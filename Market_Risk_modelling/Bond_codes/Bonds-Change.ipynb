# %%
import math
import pandas as pd
import numpy as np
import scipy
import random
import math 
from scipy import stats
from csv import reader
random.seed(120)

# %%
path1 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/historical parameters.csv"
path2 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/rates_instrument.csv"
path3 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/rates_exchange.csv"
path4 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/rates_interest.csv"
path5 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/tenor.csv"
path6 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/transaction_bond_hist_d.csv"
path7 = "/mnt/c/Users/preety.tiwari/Documents/Market_Risk_modelling/Bond_Datasets/spread_rate.csv"

# %%
def getData(path, fileext = None):
    if fileext == ".csv":
        df = pd.read_csv(path)
    elif fileext == ".xlsx" or fileext == ".xls":
        df = pd.read_excel(path)
    else:
        df = pd.read_csv(path)
    return df

# %%
hp = getData(path1)
n = hp['no_of_days']
n = list(n)
n = n[0]
decay_factor = hp['decay_factor']
holding_period = hp['holding_period']
confidence_level = hp['confidence_level']
decay_factor = list(decay_factor)
decay_factor = decay_factor[0]

# %%
hp
# Out:
#    decay_factor  holding_period  confidence_level  no_of_days  \
# 0             0              10              0.99         250
#
#    is_scenario_stressed
# 0                     0

# %% [markdown]
# # Rates Instrument

# %%
##Importing dataset rates_instrument
rates_instrument= getData(path2)

# %%
#Function to get a specific type of data from the particular column in data(Filtering)
def loadData(df, colname, types = None):
    
    res_df = df[df[colname] == types].reset_index(drop=True)
    return res_df

# %%
rates_instrument_D = loadData(rates_instrument,'instrument_type',types = 'D')
rates_instrument_E = loadData(rates_instrument,'instrument_type',types = 'E')

# %% [markdown]
# # Rates Exchange

# %%
rates_exchange = getData(path3)

# %%
rates_exchange
# Out:
#            date currency_from currency_to  rate  rate_stressed
# 0    2019-12-31           INR         INR     1              1
# 1    2019-12-30           INR         INR     1              1
# 2    2019-12-27           INR         INR     1              1
# 3    2019-12-26           INR         INR     1              1
# 4    2019-12-24           INR         INR     1              1
# ..          ...           ...         ...   ...            ...
# 246  2018-12-26           INR         INR     1              1
# 247  2018-12-24           INR         INR     1              1
# 248  2018-12-21           INR         INR     1              1
# 249  2018-12-20           INR         INR     1              1
# 250  2018-12-19           INR         INR     1              1
#
# [251 rows x 5 columns]

# %%
#Generating key
rates_exchange["key"] = rates_exchange["currency_from"] + '_' + rates_exchange["currency_to"]
rates_exchange
# Out:
#            date currency_from currency_to  rate  rate_stressed      key
# 0    2019-12-31           INR         INR     1              1  INR_INR
# 1    2019-12-30           INR         INR     1              1  INR_INR
# 2    2019-12-27           INR         INR     1              1  INR_INR
# 3    2019-12-26           INR         INR     1              1  INR_INR
# 4    2019-12-24           INR         INR     1              1  INR_INR
# ..          ...           ...         ...   ...            ...      ...
# 246  2018-12-26           INR         INR     1              1  INR_INR
# 247  2018-12-24           INR         INR     1              1  INR_INR
# 248  2018-12-21           INR         INR     1              1  INR_INR
# 249  2018-12-20           INR         INR     1              1  INR_INR
# 250  2018-12-19           INR         INR     1              1  INR_INR
#
# [251 rows x 6 columns]

# %% [markdown]
# # Rate Interest

# %%
rates_interest = getData(path4)

# %%
#Generating key between curve and tenor
rates_interest["key"] = rates_interest["curve"] + '_' + rates_interest["tenor"]
rates_interest.head()
# Out:
#          date         curve tenor  rate  rate_stressed              key
# 0  2019-12-31  INRZeroCurve    1m  4.95           4.95  INRZeroCurve_1m
# 1  2019-12-30  INRZeroCurve    1m  4.90           4.90  INRZeroCurve_1m
# 2  2019-12-27  INRZeroCurve    1m  4.90           4.90  INRZeroCurve_1m
# 3  2019-12-26  INRZeroCurve    1m  4.90           4.90  INRZeroCurve_1m
# 4  2019-12-24  INRZeroCurve    1m  4.90           4.90  INRZeroCurve_1m

# %%
##Adding current rate to the top of the rates
def sim_returns(df):
    simple_returns = pd.DataFrame([])

    for a, g in df.groupby('key'):
        
        g = g.reset_index(drop = True)
        g['simple_returns'] = g['rate']-g['rate'].shift(-1)
        #new_row = g.iloc[0].to_dict()
        #new_row['simple_returns'] = [0]
        #top_row = pd.DataFrame(new_row)
        g['simulated rates'] =( g['simple_returns'] + g['rate'].iloc[0]).shift(fill_value = g['rate'][0])
        #g = g.iloc[:-1 , :]
        #g = pd.concat([top_row, g]).reset_index(drop = True)

        simple_returns = simple_returns.append(g)
        
    
    return simple_returns

# %%
simulated_interest = sim_returns(rates_interest)
simulated_interest.head()
# Out:
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
# /tmp/ipykernel_102/2798524478.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   simple_returns = simple_returns.append(g)
#          date         curve tenor  rate  rate_stressed                key  \
# 0  2019-12-31  INRZeroCurve  025m  5.04           5.04  INRZeroCurve_025m
# 1  2019-12-30  INRZeroCurve  025m  5.00           5.00  INRZeroCurve_025m
# 2  2019-12-27  INRZeroCurve  025m  4.96           4.96  INRZeroCurve_025m
# 3  2019-12-26  INRZeroCurve  025m  5.01           5.01  INRZeroCurve_025m
# 4  2019-12-24  INRZeroCurve  025m  5.02           5.02  INRZeroCurve_025m
#
#    simple_returns  simulated rates
# 0            0.04             5.04
# 1            0.04             5.08
# 2           -0.05             5.08
# 3           -0.01             4.99
# 4            0.03             5.03

# %%
simulated_interest
# Out:
#            date         curve tenor   rate  rate_stressed                key  \
# 0    2019-12-31  INRZeroCurve  025m  5.040          5.040  INRZeroCurve_025m
# 1    2019-12-30  INRZeroCurve  025m  5.000          5.000  INRZeroCurve_025m
# 2    2019-12-27  INRZeroCurve  025m  4.960          4.960  INRZeroCurve_025m
# 3    2019-12-26  INRZeroCurve  025m  5.010          5.010  INRZeroCurve_025m
# 4    2019-12-24  INRZeroCurve  025m  5.020          5.020  INRZeroCurve_025m
# ..          ...           ...   ...    ...            ...                ...
# 246  2018-12-26  INRZeroCurve   9yr  7.371          7.371   INRZeroCurve_9yr
# 247  2018-12-24  INRZeroCurve   9yr  7.373          7.373   INRZeroCurve_9yr
# 248  2018-12-21  INRZeroCurve   9yr  7.338          7.338   INRZeroCurve_9yr
# 249  2018-12-20  INRZeroCurve   9yr  7.315          7.315   INRZeroCurve_9yr
# 250  2018-12-19  INRZeroCurve   9yr  7.315          7.315   INRZeroCurve_9yr
#
#      simple_returns  simulated rates
# 0             0.040            5.040
# 1             0.040            5.080
# 2            -0.050            5.080
# 3            -0.010            4.990
# 4             0.030            5.030
# ..              ...              ...
# 246          -0.002            6.760
# 247           0.035            6.782
# 248           0.023            6.819
# 249           0.000            6.807
# 250             NaN            6.784
#
# [5522 rows x 8 columns]

# %%
simulated_interest.iloc[250]
# Out:
# date                      2018-12-19
# curve                   INRZeroCurve
# tenor                           025m
# rate                             6.6
# rate_stressed                    6.6
# key                INRZeroCurve_025m
# simple_returns                   NaN
# simulated rates                 5.03
# Name: 250, dtype: object

# %% [markdown]
# # Tenors

# %%
tenors = getData(path5)

# %% [markdown]
# # Transaction file

# %%
tx_bond = getData(path6)
tx_bond.head(10)
# Out:
#        id       instrument  instrument_id  k currency currency_base  Cashflow  \
# 0  CGS001  IN0020100015CGS          16807  1      INR           INR      4000
# 1  CGS001  IN0020100015CGS          16807  2      INR           INR      4000
# 2  CGS001  IN0020100015CGS          16807  3      INR           INR      4000
# 3  CGS001  IN0020100015CGS          16807  4      INR           INR      4000
# 4  CGS001  IN0020100015CGS          16807  5      INR           INR      4000
# 5  CGS001  IN0020100015CGS          16807  6      INR           INR    100000
# 6  NCD001  IN1520190101NCD          16806  1      INR           INR     12750
# 7  NCD001  IN1520190101NCD          16806  2      INR           INR     12750
# 8  NCD001  IN1520190101NCD          16806  3      INR           INR     12750
# 9  NCD001  IN1520190101NCD          16806  4      INR           INR     12750
#
#   Cashflow_Type  Maturity_Amount  Face_value  ... upper_tenor lower_tenor_val  \
# 0             C           100000         100  ...        050m            025m
# 1             C           100000         100  ...       100yr            075m
# 2             C           100000         100  ...       150yr           125yr
# 3             C           100000         100  ...       200yr           175yr
# 4             C           100000         100  ...       250yr           225yr
# 5             P           100000         100  ...       250yr           225yr
# 6             C           150000         100  ...        050m            025m
# 7             C           150000         100  ...       125yr           100yr
# 8             C           150000         100  ...       225yr           200yr
# 9             C           150000         100  ...       325yr           300yr
#
#   upper_tenor_val lower_maturity upper_maturity   split_curve  \
# 0            050m             91            182  INRZeroCurve
# 1           100yr            274            366  INRZeroCurve
# 2           150yr            456            547  INRZeroCurve
# 3           200yr            639            731  INRZeroCurve
# 4           250yr            821            912  INRZeroCurve
# 5           250yr            821            912  INRZeroCurve
# 6            050m             91            182  INRZeroCurve
# 7           125yr            366            456  INRZeroCurve
# 8           225yr            731            821  INRZeroCurve
# 9           325yr           1096           1186  INRZeroCurve
#
#    accounting_book  accounting_portfolio mark_up_value intbasis
# 0                1                     1             0        1
# 1                1                     1             0        1
# 2                1                     1             0        1
# 3                1                     1             0        1
# 4                1                     1             0        1
# 5                1                     1             0        1
# 6                1                     1             0        2
# 7                1                     1             0        2
# 8                1                     1             0        2
# 9                1                     1             0        2
#
# [10 rows x 29 columns]

# %%
#print(tx_bond["instrument"],_ ,tx_bond["k"])
tx_bond["key"] = tx_bond['instrument'].map(str) + '_' + tx_bond['k'].map(str) 
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... lower_tenor_val  \
# 0       4000             C           100000         100  ...            025m
# 1       4000             C           100000         100  ...            075m
# 2       4000             C           100000         100  ...           125yr
# 3       4000             C           100000         100  ...           175yr
# 4       4000             C           100000         100  ...           225yr
# 5     100000             P           100000         100  ...           225yr
# 6      12750             C           150000         100  ...            025m
# 7      12750             C           150000         100  ...           100yr
# 8      12750             C           150000         100  ...           200yr
# 9      12750             C           150000         100  ...           300yr
# 10    150000             P           150000         100  ...           300yr
# 11      5000             C           200000         100  ...              1m
# 12      5000             C           200000         100  ...            025m
# 13      5000             C           200000         100  ...            050m
# 14      5000             C           200000         100  ...            075m
# 15      5000             C           200000         100  ...           100yr
# 16    200000             P           200000         100  ...           100yr
#
#    upper_tenor_val lower_maturity upper_maturity   split_curve  \
# 0             050m             91            182  INRZeroCurve
# 1            100yr            274            366  INRZeroCurve
# 2            150yr            456            547  INRZeroCurve
# 3            200yr            639            731  INRZeroCurve
# 4            250yr            821            912  INRZeroCurve
# 5            250yr            821            912  INRZeroCurve
# 6             050m             91            182  INRZeroCurve
# 7            125yr            366            456  INRZeroCurve
# 8            225yr            731            821  INRZeroCurve
# 9            325yr           1096           1186  INRZeroCurve
# 10           325yr           1096           1186  INRZeroCurve
# 11            025m             31             91  INRZeroCurve
# 12            050m             91            182  INRZeroCurve
# 13            075m            182            274  INRZeroCurve
# 14           100yr            274            366  INRZeroCurve
# 15           125yr            366            456  INRZeroCurve
# 16           125yr            366            456  INRZeroCurve
#
#    accounting_book  accounting_portfolio  mark_up_value intbasis  \
# 0                1                     1              0        1
# 1                1                     1              0        1
# 2                1                     1              0        1
# 3                1                     1              0        1
# 4                1                     1              0        1
# 5                1                     1              0        1
# 6                1                     1              0        2
# 7                1                     1              0        2
# 8                1                     1              0        2
# 9                1                     1              0        2
# 10               1                     1              0        2
# 11               1                     1              0        1
# 12               1                     1              0        1
# 13               1                     1              0        1
# 14               1                     1              0        1
# 15               1                     1              0        1
# 16               1                     1              0        1
#
#                   key
# 0   IN0020100015CGS_1
# 1   IN0020100015CGS_2
# 2   IN0020100015CGS_3
# 3   IN0020100015CGS_4
# 4   IN0020100015CGS_5
# 5   IN0020100015CGS_6
# 6   IN1520190101NCD_1
# 7   IN1520190101NCD_2
# 8   IN1520190101NCD_3
# 9   IN1520190101NCD_4
# 10  IN1520190101NCD_5
# 11   IN1520190101PF_1
# 12   IN1520190101PF_2
# 13   IN1520190101PF_3
# 14   IN1520190101PF_4
# 15   IN1520190101PF_5
# 16   IN1520190101PF_6
#
# [17 rows x 30 columns]

# %%
##Sorting data by'key' column
tx_bond= tx_bond.sort_values(by=['key']).reset_index(drop=True)
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... lower_tenor_val  \
# 0       4000             C           100000         100  ...            025m
# 1       4000             C           100000         100  ...            075m
# 2       4000             C           100000         100  ...           125yr
# 3       4000             C           100000         100  ...           175yr
# 4       4000             C           100000         100  ...           225yr
# 5     100000             P           100000         100  ...           225yr
# 6      12750             C           150000         100  ...            025m
# 7      12750             C           150000         100  ...           100yr
# 8      12750             C           150000         100  ...           200yr
# 9      12750             C           150000         100  ...           300yr
# 10    150000             P           150000         100  ...           300yr
# 11      5000             C           200000         100  ...              1m
# 12      5000             C           200000         100  ...            025m
# 13      5000             C           200000         100  ...            050m
# 14      5000             C           200000         100  ...            075m
# 15      5000             C           200000         100  ...           100yr
# 16    200000             P           200000         100  ...           100yr
#
#    upper_tenor_val lower_maturity upper_maturity   split_curve  \
# 0             050m             91            182  INRZeroCurve
# 1            100yr            274            366  INRZeroCurve
# 2            150yr            456            547  INRZeroCurve
# 3            200yr            639            731  INRZeroCurve
# 4            250yr            821            912  INRZeroCurve
# 5            250yr            821            912  INRZeroCurve
# 6             050m             91            182  INRZeroCurve
# 7            125yr            366            456  INRZeroCurve
# 8            225yr            731            821  INRZeroCurve
# 9            325yr           1096           1186  INRZeroCurve
# 10           325yr           1096           1186  INRZeroCurve
# 11            025m             31             91  INRZeroCurve
# 12            050m             91            182  INRZeroCurve
# 13            075m            182            274  INRZeroCurve
# 14           100yr            274            366  INRZeroCurve
# 15           125yr            366            456  INRZeroCurve
# 16           125yr            366            456  INRZeroCurve
#
#    accounting_book  accounting_portfolio  mark_up_value intbasis  \
# 0                1                     1              0        1
# 1                1                     1              0        1
# 2                1                     1              0        1
# 3                1                     1              0        1
# 4                1                     1              0        1
# 5                1                     1              0        1
# 6                1                     1              0        2
# 7                1                     1              0        2
# 8                1                     1              0        2
# 9                1                     1              0        2
# 10               1                     1              0        2
# 11               1                     1              0        1
# 12               1                     1              0        1
# 13               1                     1              0        1
# 14               1                     1              0        1
# 15               1                     1              0        1
# 16               1                     1              0        1
#
#                   key
# 0   IN0020100015CGS_1
# 1   IN0020100015CGS_2
# 2   IN0020100015CGS_3
# 3   IN0020100015CGS_4
# 4   IN0020100015CGS_5
# 5   IN0020100015CGS_6
# 6   IN1520190101NCD_1
# 7   IN1520190101NCD_2
# 8   IN1520190101NCD_3
# 9   IN1520190101NCD_4
# 10  IN1520190101NCD_5
# 11   IN1520190101PF_1
# 12   IN1520190101PF_2
# 13   IN1520190101PF_3
# 14   IN1520190101PF_4
# 15   IN1520190101PF_5
# 16   IN1520190101PF_6
#
# [17 rows x 30 columns]

# %%
#Converting to correct datetime format
tx_bond["c_date"] = pd.to_datetime(tx_bond["current_date"],format =  "%d-%m-%Y")
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... upper_tenor_val  \
# 0       4000             C           100000         100  ...            050m
# 1       4000             C           100000         100  ...           100yr
# 2       4000             C           100000         100  ...           150yr
# 3       4000             C           100000         100  ...           200yr
# 4       4000             C           100000         100  ...           250yr
# 5     100000             P           100000         100  ...           250yr
# 6      12750             C           150000         100  ...            050m
# 7      12750             C           150000         100  ...           125yr
# 8      12750             C           150000         100  ...           225yr
# 9      12750             C           150000         100  ...           325yr
# 10    150000             P           150000         100  ...           325yr
# 11      5000             C           200000         100  ...            025m
# 12      5000             C           200000         100  ...            050m
# 13      5000             C           200000         100  ...            075m
# 14      5000             C           200000         100  ...           100yr
# 15      5000             C           200000         100  ...           125yr
# 16    200000             P           200000         100  ...           125yr
#
#    lower_maturity upper_maturity   split_curve accounting_book  \
# 0              91            182  INRZeroCurve               1
# 1             274            366  INRZeroCurve               1
# 2             456            547  INRZeroCurve               1
# 3             639            731  INRZeroCurve               1
# 4             821            912  INRZeroCurve               1
# 5             821            912  INRZeroCurve               1
# 6              91            182  INRZeroCurve               1
# 7             366            456  INRZeroCurve               1
# 8             731            821  INRZeroCurve               1
# 9            1096           1186  INRZeroCurve               1
# 10           1096           1186  INRZeroCurve               1
# 11             31             91  INRZeroCurve               1
# 12             91            182  INRZeroCurve               1
# 13            182            274  INRZeroCurve               1
# 14            274            366  INRZeroCurve               1
# 15            366            456  INRZeroCurve               1
# 16            366            456  INRZeroCurve               1
#
#    accounting_portfolio  mark_up_value  intbasis                key     c_date
# 0                     1              0         1  IN0020100015CGS_1 2020-04-20
# 1                     1              0         1  IN0020100015CGS_2 2020-04-20
# 2                     1              0         1  IN0020100015CGS_3 2020-04-20
# 3                     1              0         1  IN0020100015CGS_4 2020-04-20
# 4                     1              0         1  IN0020100015CGS_5 2020-04-20
# 5                     1              0         1  IN0020100015CGS_6 2020-04-20
# 6                     1              0         2  IN1520190101NCD_1 2020-04-20
# 7                     1              0         2  IN1520190101NCD_2 2020-04-20
# 8                     1              0         2  IN1520190101NCD_3 2020-04-20
# 9                     1              0         2  IN1520190101NCD_4 2020-04-20
# 10                    1              0         2  IN1520190101NCD_5 2020-04-20
# 11                    1              0         1   IN1520190101PF_1 2020-04-20
# 12                    1              0         1   IN1520190101PF_2 2020-04-20
# 13                    1              0         1   IN1520190101PF_3 2020-04-20
# 14                    1              0         1   IN1520190101PF_4 2020-04-20
# 15                    1              0         1   IN1520190101PF_5 2020-04-20
# 16                    1              0         1   IN1520190101PF_6 2020-04-20
#
# [17 rows x 31 columns]

# %%
#Adding c_date and residual_maturity_expected column
tx_bond['m_date_E'] = tx_bond['c_date'] + pd.to_timedelta(tx_bond['residual_maturity_expected'], unit='d')
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... lower_maturity  \
# 0       4000             C           100000         100  ...             91
# 1       4000             C           100000         100  ...            274
# 2       4000             C           100000         100  ...            456
# 3       4000             C           100000         100  ...            639
# 4       4000             C           100000         100  ...            821
# 5     100000             P           100000         100  ...            821
# 6      12750             C           150000         100  ...             91
# 7      12750             C           150000         100  ...            366
# 8      12750             C           150000         100  ...            731
# 9      12750             C           150000         100  ...           1096
# 10    150000             P           150000         100  ...           1096
# 11      5000             C           200000         100  ...             31
# 12      5000             C           200000         100  ...             91
# 13      5000             C           200000         100  ...            182
# 14      5000             C           200000         100  ...            274
# 15      5000             C           200000         100  ...            366
# 16    200000             P           200000         100  ...            366
#
#    upper_maturity   split_curve accounting_book accounting_portfolio  \
# 0             182  INRZeroCurve               1                    1
# 1             366  INRZeroCurve               1                    1
# 2             547  INRZeroCurve               1                    1
# 3             731  INRZeroCurve               1                    1
# 4             912  INRZeroCurve               1                    1
# 5             912  INRZeroCurve               1                    1
# 6             182  INRZeroCurve               1                    1
# 7             456  INRZeroCurve               1                    1
# 8             821  INRZeroCurve               1                    1
# 9            1186  INRZeroCurve               1                    1
# 10           1186  INRZeroCurve               1                    1
# 11             91  INRZeroCurve               1                    1
# 12            182  INRZeroCurve               1                    1
# 13            274  INRZeroCurve               1                    1
# 14            366  INRZeroCurve               1                    1
# 15            456  INRZeroCurve               1                    1
# 16            456  INRZeroCurve               1                    1
#
#    mark_up_value  intbasis                key     c_date   m_date_E
# 0              0         1  IN0020100015CGS_1 2020-04-20 2020-08-03
# 1              0         1  IN0020100015CGS_2 2020-04-20 2021-02-03
# 2              0         1  IN0020100015CGS_3 2020-04-20 2021-08-03
# 3              0         1  IN0020100015CGS_4 2020-04-20 2022-02-03
# 4              0         1  IN0020100015CGS_5 2020-04-20 2022-08-03
# 5              0         1  IN0020100015CGS_6 2020-04-20 2022-08-03
# 6              0         2  IN1520190101NCD_1 2020-04-20 2020-08-15
# 7              0         2  IN1520190101NCD_2 2020-04-20 2021-08-15
# 8              0         2  IN1520190101NCD_3 2020-04-20 2022-08-15
# 9              0         2  IN1520190101NCD_4 2020-04-20 2023-08-15
# 10             0         2  IN1520190101NCD_5 2020-04-20 2023-08-15
# 11             0         1   IN1520190101PF_1 2020-04-20 2020-06-19
# 12             0         1   IN1520190101PF_2 2020-04-20 2020-09-19
# 13             0         1   IN1520190101PF_3 2020-04-20 2020-12-19
# 14             0         1   IN1520190101PF_4 2020-04-20 2021-03-19
# 15             0         1   IN1520190101PF_5 2020-04-20 2021-06-19
# 16             0         1   IN1520190101PF_6 2020-04-20 2021-06-19
#
# [17 rows x 32 columns]

# %%
#Adding c_date and residual_maturity_Actual column
tx_bond['m_date_A'] = tx_bond['c_date'] + pd.to_timedelta(tx_bond['residual_maturity_Actual'], unit='d')
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... upper_maturity  \
# 0       4000             C           100000         100  ...            182
# 1       4000             C           100000         100  ...            366
# 2       4000             C           100000         100  ...            547
# 3       4000             C           100000         100  ...            731
# 4       4000             C           100000         100  ...            912
# 5     100000             P           100000         100  ...            912
# 6      12750             C           150000         100  ...            182
# 7      12750             C           150000         100  ...            456
# 8      12750             C           150000         100  ...            821
# 9      12750             C           150000         100  ...           1186
# 10    150000             P           150000         100  ...           1186
# 11      5000             C           200000         100  ...             91
# 12      5000             C           200000         100  ...            182
# 13      5000             C           200000         100  ...            274
# 14      5000             C           200000         100  ...            366
# 15      5000             C           200000         100  ...            456
# 16    200000             P           200000         100  ...            456
#
#      split_curve accounting_book accounting_portfolio mark_up_value intbasis  \
# 0   INRZeroCurve               1                    1             0        1
# 1   INRZeroCurve               1                    1             0        1
# 2   INRZeroCurve               1                    1             0        1
# 3   INRZeroCurve               1                    1             0        1
# 4   INRZeroCurve               1                    1             0        1
# 5   INRZeroCurve               1                    1             0        1
# 6   INRZeroCurve               1                    1             0        2
# 7   INRZeroCurve               1                    1             0        2
# 8   INRZeroCurve               1                    1             0        2
# 9   INRZeroCurve               1                    1             0        2
# 10  INRZeroCurve               1                    1             0        2
# 11  INRZeroCurve               1                    1             0        1
# 12  INRZeroCurve               1                    1             0        1
# 13  INRZeroCurve               1                    1             0        1
# 14  INRZeroCurve               1                    1             0        1
# 15  INRZeroCurve               1                    1             0        1
# 16  INRZeroCurve               1                    1             0        1
#
#                   key     c_date   m_date_E   m_date_A
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03
# 1   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03
# 2   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03
# 3   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03
# 4   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03
# 5   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03
# 6   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16
# 7   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15
# 8   IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15
# 9   IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15
# 10  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15
# 11   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21
# 12   IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20
# 13   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20
# 14   IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21
# 15   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20
# 16   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20
#
# [17 rows x 33 columns]

# %%
tx_bond["lower_tenor_key"] = tx_bond["curve"]+ "_" + tx_bond["lower_tenor"]
tx_bond.head()
# Out:
#        id       instrument  instrument_id  k currency currency_base  Cashflow  \
# 0  CGS001  IN0020100015CGS          16807  1      INR           INR      4000
# 1  CGS001  IN0020100015CGS          16807  2      INR           INR      4000
# 2  CGS001  IN0020100015CGS          16807  3      INR           INR      4000
# 3  CGS001  IN0020100015CGS          16807  4      INR           INR      4000
# 4  CGS001  IN0020100015CGS          16807  5      INR           INR      4000
#
#   Cashflow_Type  Maturity_Amount  Face_value  ...   split_curve  \
# 0             C           100000         100  ...  INRZeroCurve
# 1             C           100000         100  ...  INRZeroCurve
# 2             C           100000         100  ...  INRZeroCurve
# 3             C           100000         100  ...  INRZeroCurve
# 4             C           100000         100  ...  INRZeroCurve
#
#   accounting_book accounting_portfolio mark_up_value intbasis  \
# 0               1                    1             0        1
# 1               1                    1             0        1
# 2               1                    1             0        1
# 3               1                    1             0        1
# 4               1                    1             0        1
#
#                  key     c_date   m_date_E   m_date_A     lower_tenor_key
# 0  IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1  IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 2  IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 3  IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 4  IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
#
# [5 rows x 34 columns]

# %%
tx_bond["upper_tenor_key"] = tx_bond["curve"]+ "_" + tx_bond["upper_tenor"]
tx_bond
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  1      INR           INR
# 12   PF001   IN1520190101PF          16803  2      INR           INR
# 13   PF001   IN1520190101PF          16803  3      INR           INR
# 14   PF001   IN1520190101PF          16803  4      INR           INR
# 15   PF001   IN1520190101PF          16803  5      INR           INR
# 16   PF001   IN1520190101PF          16803  6      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... accounting_book  \
# 0       4000             C           100000         100  ...               1
# 1       4000             C           100000         100  ...               1
# 2       4000             C           100000         100  ...               1
# 3       4000             C           100000         100  ...               1
# 4       4000             C           100000         100  ...               1
# 5     100000             P           100000         100  ...               1
# 6      12750             C           150000         100  ...               1
# 7      12750             C           150000         100  ...               1
# 8      12750             C           150000         100  ...               1
# 9      12750             C           150000         100  ...               1
# 10    150000             P           150000         100  ...               1
# 11      5000             C           200000         100  ...               1
# 12      5000             C           200000         100  ...               1
# 13      5000             C           200000         100  ...               1
# 14      5000             C           200000         100  ...               1
# 15      5000             C           200000         100  ...               1
# 16    200000             P           200000         100  ...               1
#
#    accounting_portfolio mark_up_value intbasis                key     c_date  \
# 0                     1             0        1  IN0020100015CGS_1 2020-04-20
# 1                     1             0        1  IN0020100015CGS_2 2020-04-20
# 2                     1             0        1  IN0020100015CGS_3 2020-04-20
# 3                     1             0        1  IN0020100015CGS_4 2020-04-20
# 4                     1             0        1  IN0020100015CGS_5 2020-04-20
# 5                     1             0        1  IN0020100015CGS_6 2020-04-20
# 6                     1             0        2  IN1520190101NCD_1 2020-04-20
# 7                     1             0        2  IN1520190101NCD_2 2020-04-20
# 8                     1             0        2  IN1520190101NCD_3 2020-04-20
# 9                     1             0        2  IN1520190101NCD_4 2020-04-20
# 10                    1             0        2  IN1520190101NCD_5 2020-04-20
# 11                    1             0        1   IN1520190101PF_1 2020-04-20
# 12                    1             0        1   IN1520190101PF_2 2020-04-20
# 13                    1             0        1   IN1520190101PF_3 2020-04-20
# 14                    1             0        1   IN1520190101PF_4 2020-04-20
# 15                    1             0        1   IN1520190101PF_5 2020-04-20
# 16                    1             0        1   IN1520190101PF_6 2020-04-20
#
#      m_date_E   m_date_A     lower_tenor_key     upper_tenor_key
# 0  2020-08-03 2020-08-03   INRZeroCurve_025m   INRZeroCurve_050m
# 1  2021-02-03 2021-02-03   INRZeroCurve_075m  INRZeroCurve_100yr
# 2  2021-08-03 2021-08-03  INRZeroCurve_125yr  INRZeroCurve_150yr
# 3  2022-02-03 2022-02-03  INRZeroCurve_175yr  INRZeroCurve_200yr
# 4  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr
# 5  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr
# 6  2020-08-15 2020-08-16   INRZeroCurve_025m   INRZeroCurve_050m
# 7  2021-08-15 2021-08-15  INRZeroCurve_100yr  INRZeroCurve_125yr
# 8  2022-08-15 2022-08-15  INRZeroCurve_200yr  INRZeroCurve_225yr
# 9  2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr
# 10 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr
# 11 2020-06-19 2020-06-21     INRZeroCurve_1m   INRZeroCurve_025m
# 12 2020-09-19 2020-09-20   INRZeroCurve_025m   INRZeroCurve_050m
# 13 2020-12-19 2020-12-20   INRZeroCurve_050m   INRZeroCurve_075m
# 14 2021-03-19 2021-03-21   INRZeroCurve_075m  INRZeroCurve_100yr
# 15 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr
# 16 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr
#
# [17 rows x 35 columns]

# %%
lower_tenor_key_list = list(tx_bond["lower_tenor_key"])
upper_tenor_key_list = list(tx_bond["upper_tenor_key"])
tenor_list = pd.DataFrame(lower_tenor_key_list + upper_tenor_key_list)
tenor_list = list(tenor_list[0].unique())
tenor_df = pd.DataFrame(tenor_list).reset_index(drop = True)
tenor_df = tenor_df.rename(columns = {0:'tenor_list'})

# %%
tenor_df
# Out:
#             tenor_list
# 0    INRZeroCurve_025m
# 1    INRZeroCurve_075m
# 2   INRZeroCurve_125yr
# 3   INRZeroCurve_175yr
# 4   INRZeroCurve_225yr
# 5   INRZeroCurve_100yr
# 6   INRZeroCurve_200yr
# 7   INRZeroCurve_300yr
# 8      INRZeroCurve_1m
# 9    INRZeroCurve_050m
# 10  INRZeroCurve_150yr
# 11  INRZeroCurve_250yr
# 12  INRZeroCurve_325yr

# %%
# #tenor_list_unique = tenor_list_unique.rename(columns = {0:'tenor_list_unique'})
# tenor_df = tenor_df.sort_values('tenor_list')
# tenor_df = tenor_df.reset_index(drop=True)

# %%
tenor_df
# Out:
#             tenor_list
# 0    INRZeroCurve_025m
# 1    INRZeroCurve_075m
# 2   INRZeroCurve_125yr
# 3   INRZeroCurve_175yr
# 4   INRZeroCurve_225yr
# 5   INRZeroCurve_100yr
# 6   INRZeroCurve_200yr
# 7   INRZeroCurve_300yr
# 8      INRZeroCurve_1m
# 9    INRZeroCurve_050m
# 10  INRZeroCurve_150yr
# 11  INRZeroCurve_250yr
# 12  INRZeroCurve_325yr

# %% [markdown]
# Matching the key values of simulated_interest dataframe with the tenor_list_unique key values of tenor_list_unique dataframe
# and dropped out the columns 'key','date','rate_stressed','simple_returns','simulated rates'.

# %%
rates_interest_current = pd.merge(tenor_df,simulated_interest,how='left',left_on='tenor_list',right_on='key').drop(['key','date','rate_stressed','simple_returns','rate'], axis=1)

# %%
rates_interest_current.head(50)
# Out:
#            tenor_list         curve tenor  simulated rates
# 0   INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 1   INRZeroCurve_025m  INRZeroCurve  025m             5.08
# 2   INRZeroCurve_025m  INRZeroCurve  025m             5.08
# 3   INRZeroCurve_025m  INRZeroCurve  025m             4.99
# 4   INRZeroCurve_025m  INRZeroCurve  025m             5.03
# 5   INRZeroCurve_025m  INRZeroCurve  025m             5.07
# 6   INRZeroCurve_025m  INRZeroCurve  025m             5.02
# 7   INRZeroCurve_025m  INRZeroCurve  025m             5.06
# 8   INRZeroCurve_025m  INRZeroCurve  025m             5.03
# 9   INRZeroCurve_025m  INRZeroCurve  025m             5.01
# 10  INRZeroCurve_025m  INRZeroCurve  025m             5.06
# 11  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 12  INRZeroCurve_025m  INRZeroCurve  025m             5.02
# 13  INRZeroCurve_025m  INRZeroCurve  025m             5.07
# 14  INRZeroCurve_025m  INRZeroCurve  025m             5.03
# 15  INRZeroCurve_025m  INRZeroCurve  025m             5.00
# 16  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 17  INRZeroCurve_025m  INRZeroCurve  025m             5.12
# 18  INRZeroCurve_025m  INRZeroCurve  025m             5.11
# 19  INRZeroCurve_025m  INRZeroCurve  025m             5.01
# 20  INRZeroCurve_025m  INRZeroCurve  025m             5.01
# 21  INRZeroCurve_025m  INRZeroCurve  025m             5.10
# 22  INRZeroCurve_025m  INRZeroCurve  025m             4.97
# 23  INRZeroCurve_025m  INRZeroCurve  025m             4.97
# 24  INRZeroCurve_025m  INRZeroCurve  025m             5.00
# 25  INRZeroCurve_025m  INRZeroCurve  025m             5.07
# 26  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 27  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 28  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 29  INRZeroCurve_025m  INRZeroCurve  025m             5.01
# 30  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 31  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 32  INRZeroCurve_025m  INRZeroCurve  025m             5.03
# 33  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 34  INRZeroCurve_025m  INRZeroCurve  025m             5.02
# 35  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 36  INRZeroCurve_025m  INRZeroCurve  025m             5.06
# 37  INRZeroCurve_025m  INRZeroCurve  025m             5.06
# 38  INRZeroCurve_025m  INRZeroCurve  025m             5.03
# 39  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 40  INRZeroCurve_025m  INRZeroCurve  025m             5.07
# 41  INRZeroCurve_025m  INRZeroCurve  025m             5.02
# 42  INRZeroCurve_025m  INRZeroCurve  025m             5.01
# 43  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 44  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 45  INRZeroCurve_025m  INRZeroCurve  025m             5.05
# 46  INRZeroCurve_025m  INRZeroCurve  025m             5.00
# 47  INRZeroCurve_025m  INRZeroCurve  025m             5.06
# 48  INRZeroCurve_025m  INRZeroCurve  025m             5.04
# 49  INRZeroCurve_025m  INRZeroCurve  025m             5.04

# %%
rates_interest_current.shape
# Out:
# (3263, 4)

# %%
tenor_rates = (rates_interest_current.drop_duplicates(['tenor_list']))
tenor_rates = tenor_rates.reset_index(drop=True)
tenor_rates
# Out:
#             tenor_list         curve  tenor  simulated rates
# 0    INRZeroCurve_025m  INRZeroCurve   025m            5.040
# 1    INRZeroCurve_075m  INRZeroCurve   075m            5.190
# 2   INRZeroCurve_125yr  INRZeroCurve  125yr            5.190
# 3   INRZeroCurve_175yr  INRZeroCurve  175yr            5.190
# 4   INRZeroCurve_225yr  INRZeroCurve  225yr            5.776
# 5   INRZeroCurve_100yr  INRZeroCurve  100yr            5.190
# 6   INRZeroCurve_200yr  INRZeroCurve  200yr            5.776
# 7   INRZeroCurve_300yr  INRZeroCurve  300yr            6.357
# 8      INRZeroCurve_1m  INRZeroCurve     1m            4.950
# 9    INRZeroCurve_050m  INRZeroCurve   050m            5.170
# 10  INRZeroCurve_150yr  INRZeroCurve  150yr            6.110
# 11  INRZeroCurve_250yr  INRZeroCurve  250yr            5.776
# 12  INRZeroCurve_325yr  INRZeroCurve  325yr            6.357

# %%
tx_bond_new = tx_bond.merge(tenor_rates,how='inner',left_on='lower_tenor_key',right_on='tenor_list')

# %%
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1      12750             C           150000         100  ...
# 2       5000             C           200000         100  ...
# 3       4000             C           100000         100  ...
# 4       5000             C           200000         100  ...
# 5       4000             C           100000         100  ...
# 6       4000             C           100000         100  ...
# 7       4000             C           100000         100  ...
# 8     100000             P           100000         100  ...
# 9      12750             C           150000         100  ...
# 10      5000             C           200000         100  ...
# 11    200000             P           200000         100  ...
# 12     12750             C           150000         100  ...
# 13     12750             C           150000         100  ...
# 14    150000             P           150000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#                   key     c_date   m_date_E   m_date_A     lower_tenor_key  \
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16   INRZeroCurve_025m
# 2    IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20   INRZeroCurve_025m
# 3   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 4    IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21   INRZeroCurve_075m
# 5   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 6   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 7   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 8   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 9   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15  INRZeroCurve_100yr
# 10   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 11   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 12  IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15  INRZeroCurve_200yr
# 13  IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 14  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 15   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21     INRZeroCurve_1m
# 16   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20   INRZeroCurve_050m
#
#        upper_tenor_key          tenor_list       curve_y  tenor  \
# 0    INRZeroCurve_050m   INRZeroCurve_025m  INRZeroCurve   025m
# 1    INRZeroCurve_050m   INRZeroCurve_025m  INRZeroCurve   025m
# 2    INRZeroCurve_050m   INRZeroCurve_025m  INRZeroCurve   025m
# 3   INRZeroCurve_100yr   INRZeroCurve_075m  INRZeroCurve   075m
# 4   INRZeroCurve_100yr   INRZeroCurve_075m  INRZeroCurve   075m
# 5   INRZeroCurve_150yr  INRZeroCurve_125yr  INRZeroCurve  125yr
# 6   INRZeroCurve_200yr  INRZeroCurve_175yr  INRZeroCurve  175yr
# 7   INRZeroCurve_250yr  INRZeroCurve_225yr  INRZeroCurve  225yr
# 8   INRZeroCurve_250yr  INRZeroCurve_225yr  INRZeroCurve  225yr
# 9   INRZeroCurve_125yr  INRZeroCurve_100yr  INRZeroCurve  100yr
# 10  INRZeroCurve_125yr  INRZeroCurve_100yr  INRZeroCurve  100yr
# 11  INRZeroCurve_125yr  INRZeroCurve_100yr  INRZeroCurve  100yr
# 12  INRZeroCurve_225yr  INRZeroCurve_200yr  INRZeroCurve  200yr
# 13  INRZeroCurve_325yr  INRZeroCurve_300yr  INRZeroCurve  300yr
# 14  INRZeroCurve_325yr  INRZeroCurve_300yr  INRZeroCurve  300yr
# 15   INRZeroCurve_025m     INRZeroCurve_1m  INRZeroCurve     1m
# 16   INRZeroCurve_075m   INRZeroCurve_050m  INRZeroCurve   050m
#
#    simulated rates
# 0            5.040
# 1            5.040
# 2            5.040
# 3            5.190
# 4            5.190
# 5            5.190
# 6            5.190
# 7            5.776
# 8            5.776
# 9            5.190
# 10           5.190
# 11           5.190
# 12           5.776
# 13           6.357
# 14           6.357
# 15           4.950
# 16           5.170
#
# [17 rows x 39 columns]

# %%
tx_bond_new.shape
# Out:
# (17, 39)

# %%
list(tx_bond_new.columns)
# Out:
# ['id',
#  'instrument',
#  'instrument_id',
#  'k',
#  'currency',
#  'currency_base',
#  'Cashflow',
#  'Cashflow_Type',
#  'Maturity_Amount',
#  'Face_value',
#  'curve_x',
#  'current_date',
#  'Cash_flow_Dates',
#  'holiday',
#  'Actual_Cash_flow_date',
#  'maturity_date',
#  'residual_maturity_expected',
#  'residual_maturity_Actual',
#  'lower_tenor',
#  'upper_tenor',
#  'lower_tenor_val',
#  'upper_tenor_val',
#  'lower_maturity',
#  'upper_maturity',
#  'split_curve',
#  'accounting_book',
#  'accounting_portfolio',
#  'mark_up_value',
#  'intbasis',
#  'key',
#  'c_date',
#  'm_date_E',
#  'm_date_A',
#  'lower_tenor_key',
#  'upper_tenor_key',
#  'tenor_list',
#  'curve_y',
#  'tenor',
#  'simulated rates']

# %%
from copy import deepcopy

# %%
test_rate_df = deepcopy(rates_interest_current)

test_rate_df

#(test_rate_df.drop_duplicates(['tenor_list_unique']))
# Out:
#               tenor_list         curve  tenor  simulated rates
# 0      INRZeroCurve_025m  INRZeroCurve   025m            5.040
# 1      INRZeroCurve_025m  INRZeroCurve   025m            5.080
# 2      INRZeroCurve_025m  INRZeroCurve   025m            5.080
# 3      INRZeroCurve_025m  INRZeroCurve   025m            4.990
# 4      INRZeroCurve_025m  INRZeroCurve   025m            5.030
# ...                  ...           ...    ...              ...
# 3258  INRZeroCurve_325yr  INRZeroCurve  325yr            6.367
# 3259  INRZeroCurve_325yr  INRZeroCurve  325yr            6.307
# 3260  INRZeroCurve_325yr  INRZeroCurve  325yr            6.367
# 3261  INRZeroCurve_325yr  INRZeroCurve  325yr            6.357
# 3262  INRZeroCurve_325yr  INRZeroCurve  325yr            6.357
#
# [3263 rows x 4 columns]

# %%
rates_interest_current_1V = (test_rate_df.drop_duplicates(['tenor_list']))
rates_interest_current_1V = rates_interest_current_1V.reset_index(drop=True)
rates_interest_current_1V
# Out:
#             tenor_list         curve  tenor  simulated rates
# 0    INRZeroCurve_025m  INRZeroCurve   025m            5.040
# 1    INRZeroCurve_075m  INRZeroCurve   075m            5.190
# 2   INRZeroCurve_125yr  INRZeroCurve  125yr            5.190
# 3   INRZeroCurve_175yr  INRZeroCurve  175yr            5.190
# 4   INRZeroCurve_225yr  INRZeroCurve  225yr            5.776
# 5   INRZeroCurve_100yr  INRZeroCurve  100yr            5.190
# 6   INRZeroCurve_200yr  INRZeroCurve  200yr            5.776
# 7   INRZeroCurve_300yr  INRZeroCurve  300yr            6.357
# 8      INRZeroCurve_1m  INRZeroCurve     1m            4.950
# 9    INRZeroCurve_050m  INRZeroCurve   050m            5.170
# 10  INRZeroCurve_150yr  INRZeroCurve  150yr            6.110
# 11  INRZeroCurve_250yr  INRZeroCurve  250yr            5.776
# 12  INRZeroCurve_325yr  INRZeroCurve  325yr            6.357

# %% [markdown]
# Correct till here

# %%
rates_interest_current.iloc[251]
# Out:
# tenor_list         INRZeroCurve_075m
# curve                   INRZeroCurve
# tenor                           075m
# simulated rates                 5.19
# Name: 251, dtype: object

# %%
##Sorting rates_interest_current df tenor wise and reset index
# rates_interest_current= rates_interest_current.sort_values(by=['tenor'])
# rates_interest_current.reset_index(drop=True)

# %%
###Filtering according to Instrument
rates_interest_current_1S = rates_interest_current.filter(['tenor_list', 'simulated rates']) ##To extract particular columns
rates_interest_current_1S
# Out:
#               tenor_list  simulated rates
# 0      INRZeroCurve_025m            5.040
# 1      INRZeroCurve_025m            5.080
# 2      INRZeroCurve_025m            5.080
# 3      INRZeroCurve_025m            4.990
# 4      INRZeroCurve_025m            5.030
# ...                  ...              ...
# 3258  INRZeroCurve_325yr            6.367
# 3259  INRZeroCurve_325yr            6.307
# 3260  INRZeroCurve_325yr            6.367
# 3261  INRZeroCurve_325yr            6.357
# 3262  INRZeroCurve_325yr            6.357
#
# [3263 rows x 2 columns]

# %%
rates_interest_current_1S = rates_interest_current_1S.set_index('tenor_list')
rates_interest_current_1S
# Out:
#                     simulated rates
# tenor_list
# INRZeroCurve_025m             5.040
# INRZeroCurve_025m             5.080
# INRZeroCurve_025m             5.080
# INRZeroCurve_025m             4.990
# INRZeroCurve_025m             5.030
# ...                             ...
# INRZeroCurve_325yr            6.367
# INRZeroCurve_325yr            6.307
# INRZeroCurve_325yr            6.367
# INRZeroCurve_325yr            6.357
# INRZeroCurve_325yr            6.357
#
# [3263 rows x 1 columns]

# %%
##Fetching current values for each of the tenor_list_unique

# %%
##Segregating simulations according to the tenor_list_unique(unique key) generated
df = (rates_interest_current_1S.assign(labels = rates_interest_current_1S.groupby(level = 0).cumcount())
            .groupby([rates_interest_current_1S.index,'labels']).first()
            .unstack('labels')
            .sort_index(axis =1,level = 1)
            .droplevel(1,axis = 1))
df
# Out:
#                     simulated rates  simulated rates  simulated rates  \
# tenor_list
# INRZeroCurve_025m             5.040            5.080            5.080
# INRZeroCurve_050m             5.170            5.140            5.200
# INRZeroCurve_075m             5.190            5.160            5.150
# INRZeroCurve_100yr            5.190            5.160            5.150
# INRZeroCurve_125yr            5.190            5.160            5.150
# INRZeroCurve_150yr            6.110            6.110            6.110
# INRZeroCurve_175yr            5.190            5.160            5.150
# INRZeroCurve_1m               4.950            5.000            4.950
# INRZeroCurve_200yr            5.776            5.721            5.787
# INRZeroCurve_225yr            5.776            5.721            5.787
# INRZeroCurve_250yr            5.776            5.721            5.787
# INRZeroCurve_300yr            6.357            6.376            6.377
# INRZeroCurve_325yr            6.357            6.604            6.357
#
#                     simulated rates  simulated rates  simulated rates  \
# tenor_list
# INRZeroCurve_025m             4.990            5.030            5.070
# INRZeroCurve_050m             5.180            5.130            5.180
# INRZeroCurve_075m             5.200            5.150            5.220
# INRZeroCurve_100yr            5.200            5.150            5.220
# INRZeroCurve_125yr            5.200            5.150            5.220
# INRZeroCurve_150yr            6.110            6.110            6.110
# INRZeroCurve_175yr            5.200            5.150            5.220
# INRZeroCurve_1m               4.950            4.950            4.950
# INRZeroCurve_200yr            5.808            5.755            5.748
# INRZeroCurve_225yr            5.808            5.755            5.748
# INRZeroCurve_250yr            5.808            5.755            5.748
# INRZeroCurve_300yr            6.371            6.382            6.359
# INRZeroCurve_325yr            6.357            6.357            6.357
#
#                     simulated rates  simulated rates  simulated rates  \
# tenor_list
# INRZeroCurve_025m             5.020            5.060            5.030
# INRZeroCurve_050m             5.150            5.190            5.180
# INRZeroCurve_075m             5.130            5.200            5.200
# INRZeroCurve_100yr            5.130            5.200            5.200
# INRZeroCurve_125yr            5.130            5.200            5.200
# INRZeroCurve_150yr            6.110            6.110            6.110
# INRZeroCurve_175yr            5.130            5.200            5.200
# INRZeroCurve_1m               4.880            4.970            4.970
# INRZeroCurve_200yr            5.735            5.835            5.809
# INRZeroCurve_225yr            5.735            5.835            5.809
# INRZeroCurve_250yr            5.735            5.835            5.809
# INRZeroCurve_300yr            6.353            6.291            6.353
# INRZeroCurve_325yr            6.357            6.357            6.357
#
#                     simulated rates  ...  simulated rates  simulated rates  \
# tenor_list                           ...
# INRZeroCurve_025m             5.010  ...            5.020            5.050
# INRZeroCurve_050m             5.150  ...            5.150            5.120
# INRZeroCurve_075m             5.230  ...            5.190            5.190
# INRZeroCurve_100yr            5.230  ...            5.170            5.160
# INRZeroCurve_125yr            5.230  ...            5.170            5.160
# INRZeroCurve_150yr            6.110  ...            6.090            6.080
# INRZeroCurve_175yr            5.230  ...            5.170            5.160
# INRZeroCurve_1m               4.910  ...            4.930            4.960
# INRZeroCurve_200yr            5.741  ...            5.729            5.798
# INRZeroCurve_225yr            5.741  ...            5.729            5.798
# INRZeroCurve_250yr            5.741  ...            5.729            5.798
# INRZeroCurve_300yr            6.339  ...            6.337            6.309
# INRZeroCurve_325yr            6.357  ...            6.337            6.327
#
#                     simulated rates  simulated rates  simulated rates  \
# tenor_list
# INRZeroCurve_025m             4.900            5.060            5.110
# INRZeroCurve_050m             5.160            5.180            5.160
# INRZeroCurve_075m             5.190            5.190            5.190
# INRZeroCurve_100yr            5.200            5.180            5.200
# INRZeroCurve_125yr            5.200            5.180            5.200
# INRZeroCurve_150yr            6.120            6.100            6.120
# INRZeroCurve_175yr            5.200            5.180            5.200
# INRZeroCurve_1m               4.840            4.910            4.950
# INRZeroCurve_200yr            5.743            5.788            5.779
# INRZeroCurve_225yr            5.743            5.788            5.779
# INRZeroCurve_250yr            5.743            5.788            5.779
# INRZeroCurve_300yr            6.367            6.404            6.355
# INRZeroCurve_325yr            6.367            6.347            6.367
#
#                     simulated rates  simulated rates  simulated rates  \
# tenor_list
# INRZeroCurve_025m             5.040            4.960            5.040
# INRZeroCurve_050m             5.190            5.190            5.150
# INRZeroCurve_075m             5.190            5.190            5.190
# INRZeroCurve_100yr            5.200            5.140            5.200
# INRZeroCurve_125yr            5.200            5.140            5.200
# INRZeroCurve_150yr            6.120            6.060            6.120
# INRZeroCurve_175yr            5.200            5.140            5.200
# INRZeroCurve_1m               4.960            5.000            4.890
# INRZeroCurve_200yr            5.743            5.824            5.723
# INRZeroCurve_225yr            5.743            5.824            5.723
# INRZeroCurve_250yr            5.743            5.824            5.723
# INRZeroCurve_300yr            6.336            6.358            6.356
# INRZeroCurve_325yr            6.367            6.307            6.367
#
#                     simulated rates  simulated rates
# tenor_list
# INRZeroCurve_025m             5.190            5.030
# INRZeroCurve_050m             5.150            5.160
# INRZeroCurve_075m             5.190            5.190
# INRZeroCurve_100yr            5.190            5.190
# INRZeroCurve_125yr            5.190            5.190
# INRZeroCurve_150yr            6.110            6.110
# INRZeroCurve_175yr            5.190            5.190
# INRZeroCurve_1m               5.020            4.940
# INRZeroCurve_200yr            5.793            5.776
# INRZeroCurve_225yr            5.793            5.776
# INRZeroCurve_250yr            5.793            5.776
# INRZeroCurve_300yr            6.363            6.357
# INRZeroCurve_325yr            6.357            6.357
#
# [13 rows x 251 columns]

# %%
#Extracting values at 0th index
tenor_rates = df.iloc[:,0]
tenor_rates
# Out:
# tenor_list
# INRZeroCurve_025m     5.040
# INRZeroCurve_050m     5.170
# INRZeroCurve_075m     5.190
# INRZeroCurve_100yr    5.190
# INRZeroCurve_125yr    5.190
# INRZeroCurve_150yr    6.110
# INRZeroCurve_175yr    5.190
# INRZeroCurve_1m       4.950
# INRZeroCurve_200yr    5.776
# INRZeroCurve_225yr    5.776
# INRZeroCurve_250yr    5.776
# INRZeroCurve_300yr    6.357
# INRZeroCurve_325yr    6.357
# Name: simulated rates, dtype: float64

# %%
tenor_rates_df_V = pd.DataFrame(tenor_rates)

# %%
tenor_rates_df_V
# Out:
#                     simulated rates
# tenor_list
# INRZeroCurve_025m             5.040
# INRZeroCurve_050m             5.170
# INRZeroCurve_075m             5.190
# INRZeroCurve_100yr            5.190
# INRZeroCurve_125yr            5.190
# INRZeroCurve_150yr            6.110
# INRZeroCurve_175yr            5.190
# INRZeroCurve_1m               4.950
# INRZeroCurve_200yr            5.776
# INRZeroCurve_225yr            5.776
# INRZeroCurve_250yr            5.776
# INRZeroCurve_300yr            6.357
# INRZeroCurve_325yr            6.357

# %%
# tenor_rates_df = pd.DataFrame(tenor_rates,columns=['rate'])
# tenor_rates_df.head()

# %%
type(tenor_rates_df_V)
# Out:
# pandas.core.frame.DataFrame

# %%
tenor_rates_df_V.index.rename('key',inplace=True)

# %%
tenor_rates_df_V.head()
# Out:
#                     simulated rates
# key
# INRZeroCurve_025m              5.04
# INRZeroCurve_050m              5.17
# INRZeroCurve_075m              5.19
# INRZeroCurve_100yr             5.19
# INRZeroCurve_125yr             5.19

# %% [markdown]
# Match lower tenor key with the tenor_rate df and get the corresponding rate values.
# Match upper tenor key with the tenor_rate df and get the corresponding rate values

# %%
tenor_rates_df_V
# Out:
#                     simulated rates
# key
# INRZeroCurve_025m             5.040
# INRZeroCurve_050m             5.170
# INRZeroCurve_075m             5.190
# INRZeroCurve_100yr            5.190
# INRZeroCurve_125yr            5.190
# INRZeroCurve_150yr            6.110
# INRZeroCurve_175yr            5.190
# INRZeroCurve_1m               4.950
# INRZeroCurve_200yr            5.776
# INRZeroCurve_225yr            5.776
# INRZeroCurve_250yr            5.776
# INRZeroCurve_300yr            6.357
# INRZeroCurve_325yr            6.357

# %%
tx_bond_new = tx_bond.merge(tenor_rates_df_V,how='inner',left_on='lower_tenor_key',right_on='key')

# %%
#tx_bond_new = tx_bond_new.sort_values(by = ['lower_tenor_key'])

# %%
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1      12750             C           150000         100  ...
# 2       5000             C           200000         100  ...
# 3       4000             C           100000         100  ...
# 4       5000             C           200000         100  ...
# 5       4000             C           100000         100  ...
# 6       4000             C           100000         100  ...
# 7       4000             C           100000         100  ...
# 8     100000             P           100000         100  ...
# 9      12750             C           150000         100  ...
# 10      5000             C           200000         100  ...
# 11    200000             P           200000         100  ...
# 12     12750             C           150000         100  ...
# 13     12750             C           150000         100  ...
# 14    150000             P           150000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#    accounting_portfolio mark_up_value intbasis                key     c_date  \
# 0                     1             0        1  IN0020100015CGS_1 2020-04-20
# 1                     1             0        2  IN1520190101NCD_1 2020-04-20
# 2                     1             0        1   IN1520190101PF_2 2020-04-20
# 3                     1             0        1  IN0020100015CGS_2 2020-04-20
# 4                     1             0        1   IN1520190101PF_4 2020-04-20
# 5                     1             0        1  IN0020100015CGS_3 2020-04-20
# 6                     1             0        1  IN0020100015CGS_4 2020-04-20
# 7                     1             0        1  IN0020100015CGS_5 2020-04-20
# 8                     1             0        1  IN0020100015CGS_6 2020-04-20
# 9                     1             0        2  IN1520190101NCD_2 2020-04-20
# 10                    1             0        1   IN1520190101PF_5 2020-04-20
# 11                    1             0        1   IN1520190101PF_6 2020-04-20
# 12                    1             0        2  IN1520190101NCD_3 2020-04-20
# 13                    1             0        2  IN1520190101NCD_4 2020-04-20
# 14                    1             0        2  IN1520190101NCD_5 2020-04-20
# 15                    1             0        1   IN1520190101PF_1 2020-04-20
# 16                    1             0        1   IN1520190101PF_3 2020-04-20
#
#      m_date_E   m_date_A     lower_tenor_key     upper_tenor_key  \
# 0  2020-08-03 2020-08-03   INRZeroCurve_025m   INRZeroCurve_050m
# 1  2020-08-15 2020-08-16   INRZeroCurve_025m   INRZeroCurve_050m
# 2  2020-09-19 2020-09-20   INRZeroCurve_025m   INRZeroCurve_050m
# 3  2021-02-03 2021-02-03   INRZeroCurve_075m  INRZeroCurve_100yr
# 4  2021-03-19 2021-03-21   INRZeroCurve_075m  INRZeroCurve_100yr
# 5  2021-08-03 2021-08-03  INRZeroCurve_125yr  INRZeroCurve_150yr
# 6  2022-02-03 2022-02-03  INRZeroCurve_175yr  INRZeroCurve_200yr
# 7  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr
# 8  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr
# 9  2021-08-15 2021-08-15  INRZeroCurve_100yr  INRZeroCurve_125yr
# 10 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr
# 11 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr
# 12 2022-08-15 2022-08-15  INRZeroCurve_200yr  INRZeroCurve_225yr
# 13 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr
# 14 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr
# 15 2020-06-19 2020-06-21     INRZeroCurve_1m   INRZeroCurve_025m
# 16 2020-12-19 2020-12-20   INRZeroCurve_050m   INRZeroCurve_075m
#
#    simulated rates
# 0            5.040
# 1            5.040
# 2            5.040
# 3            5.190
# 4            5.190
# 5            5.190
# 6            5.190
# 7            5.776
# 8            5.776
# 9            5.190
# 10           5.190
# 11           5.190
# 12           5.776
# 13           6.357
# 14           6.357
# 15           4.950
# 16           5.170
#
# [17 rows x 36 columns]

# %%
##Renaming the rate column
tx_bond_new = tx_bond_new.rename(columns = {'simulated rates':'lower_rates'})
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1      12750             C           150000         100  ...
# 2       5000             C           200000         100  ...
# 3       4000             C           100000         100  ...
# 4       5000             C           200000         100  ...
# 5       4000             C           100000         100  ...
# 6       4000             C           100000         100  ...
# 7       4000             C           100000         100  ...
# 8     100000             P           100000         100  ...
# 9      12750             C           150000         100  ...
# 10      5000             C           200000         100  ...
# 11    200000             P           200000         100  ...
# 12     12750             C           150000         100  ...
# 13     12750             C           150000         100  ...
# 14    150000             P           150000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#    accounting_portfolio mark_up_value intbasis                key     c_date  \
# 0                     1             0        1  IN0020100015CGS_1 2020-04-20
# 1                     1             0        2  IN1520190101NCD_1 2020-04-20
# 2                     1             0        1   IN1520190101PF_2 2020-04-20
# 3                     1             0        1  IN0020100015CGS_2 2020-04-20
# 4                     1             0        1   IN1520190101PF_4 2020-04-20
# 5                     1             0        1  IN0020100015CGS_3 2020-04-20
# 6                     1             0        1  IN0020100015CGS_4 2020-04-20
# 7                     1             0        1  IN0020100015CGS_5 2020-04-20
# 8                     1             0        1  IN0020100015CGS_6 2020-04-20
# 9                     1             0        2  IN1520190101NCD_2 2020-04-20
# 10                    1             0        1   IN1520190101PF_5 2020-04-20
# 11                    1             0        1   IN1520190101PF_6 2020-04-20
# 12                    1             0        2  IN1520190101NCD_3 2020-04-20
# 13                    1             0        2  IN1520190101NCD_4 2020-04-20
# 14                    1             0        2  IN1520190101NCD_5 2020-04-20
# 15                    1             0        1   IN1520190101PF_1 2020-04-20
# 16                    1             0        1   IN1520190101PF_3 2020-04-20
#
#      m_date_E   m_date_A     lower_tenor_key     upper_tenor_key lower_rates
# 0  2020-08-03 2020-08-03   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 1  2020-08-15 2020-08-16   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 2  2020-09-19 2020-09-20   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 3  2021-02-03 2021-02-03   INRZeroCurve_075m  INRZeroCurve_100yr       5.190
# 4  2021-03-19 2021-03-21   INRZeroCurve_075m  INRZeroCurve_100yr       5.190
# 5  2021-08-03 2021-08-03  INRZeroCurve_125yr  INRZeroCurve_150yr       5.190
# 6  2022-02-03 2022-02-03  INRZeroCurve_175yr  INRZeroCurve_200yr       5.190
# 7  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776
# 8  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776
# 9  2021-08-15 2021-08-15  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 10 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 11 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 12 2022-08-15 2022-08-15  INRZeroCurve_200yr  INRZeroCurve_225yr       5.776
# 13 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357
# 14 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357
# 15 2020-06-19 2020-06-21     INRZeroCurve_1m   INRZeroCurve_025m       4.950
# 16 2020-12-19 2020-12-20   INRZeroCurve_050m   INRZeroCurve_075m       5.170
#
# [17 rows x 36 columns]

# %%
#Upper rates
tx_bond_new = tx_bond_new.merge(tenor_rates_df_V, how='inner', left_on='upper_tenor_key', right_on='key')

# %%
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... mark_up_value  \
# 0       4000             C           100000         100  ...             0
# 1      12750             C           150000         100  ...             0
# 2       5000             C           200000         100  ...             0
# 3       4000             C           100000         100  ...             0
# 4       5000             C           200000         100  ...             0
# 5       4000             C           100000         100  ...             0
# 6       4000             C           100000         100  ...             0
# 7       4000             C           100000         100  ...             0
# 8     100000             P           100000         100  ...             0
# 9      12750             C           150000         100  ...             0
# 10      5000             C           200000         100  ...             0
# 11    200000             P           200000         100  ...             0
# 12     12750             C           150000         100  ...             0
# 13     12750             C           150000         100  ...             0
# 14    150000             P           150000         100  ...             0
# 15      5000             C           200000         100  ...             0
# 16      5000             C           200000         100  ...             0
#
#    intbasis                key     c_date   m_date_E   m_date_A  \
# 0         1  IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03
# 1         2  IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16
# 2         1   IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20
# 3         1  IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03
# 4         1   IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21
# 5         1  IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03
# 6         1  IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03
# 7         1  IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03
# 8         1  IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03
# 9         2  IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15
# 10        1   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20
# 11        1   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20
# 12        2  IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15
# 13        2  IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15
# 14        2  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15
# 15        1   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21
# 16        1   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20
#
#        lower_tenor_key     upper_tenor_key lower_rates simulated rates
# 0    INRZeroCurve_025m   INRZeroCurve_050m       5.040           5.170
# 1    INRZeroCurve_025m   INRZeroCurve_050m       5.040           5.170
# 2    INRZeroCurve_025m   INRZeroCurve_050m       5.040           5.170
# 3    INRZeroCurve_075m  INRZeroCurve_100yr       5.190           5.190
# 4    INRZeroCurve_075m  INRZeroCurve_100yr       5.190           5.190
# 5   INRZeroCurve_125yr  INRZeroCurve_150yr       5.190           6.110
# 6   INRZeroCurve_175yr  INRZeroCurve_200yr       5.190           5.776
# 7   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776           5.776
# 8   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776           5.776
# 9   INRZeroCurve_100yr  INRZeroCurve_125yr       5.190           5.190
# 10  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190           5.190
# 11  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190           5.190
# 12  INRZeroCurve_200yr  INRZeroCurve_225yr       5.776           5.776
# 13  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357           6.357
# 14  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357           6.357
# 15     INRZeroCurve_1m   INRZeroCurve_025m       4.950           5.040
# 16   INRZeroCurve_050m   INRZeroCurve_075m       5.170           5.190
#
# [17 rows x 37 columns]

# %%
#tx_bond_new = tx_bond_new.sort_values(by = ['upper_tenor_key'])

# %%
tx_bond_new =  tx_bond_new.rename(columns = {'simulated rates':'upper_rates'})

# %%
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... mark_up_value  \
# 0       4000             C           100000         100  ...             0
# 1      12750             C           150000         100  ...             0
# 2       5000             C           200000         100  ...             0
# 3       4000             C           100000         100  ...             0
# 4       5000             C           200000         100  ...             0
# 5       4000             C           100000         100  ...             0
# 6       4000             C           100000         100  ...             0
# 7       4000             C           100000         100  ...             0
# 8     100000             P           100000         100  ...             0
# 9      12750             C           150000         100  ...             0
# 10      5000             C           200000         100  ...             0
# 11    200000             P           200000         100  ...             0
# 12     12750             C           150000         100  ...             0
# 13     12750             C           150000         100  ...             0
# 14    150000             P           150000         100  ...             0
# 15      5000             C           200000         100  ...             0
# 16      5000             C           200000         100  ...             0
#
#    intbasis                key     c_date   m_date_E   m_date_A  \
# 0         1  IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03
# 1         2  IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16
# 2         1   IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20
# 3         1  IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03
# 4         1   IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21
# 5         1  IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03
# 6         1  IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03
# 7         1  IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03
# 8         1  IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03
# 9         2  IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15
# 10        1   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20
# 11        1   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20
# 12        2  IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15
# 13        2  IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15
# 14        2  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15
# 15        1   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21
# 16        1   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20
#
#        lower_tenor_key     upper_tenor_key lower_rates upper_rates
# 0    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 1    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 2    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 3    INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 4    INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 5   INRZeroCurve_125yr  INRZeroCurve_150yr       5.190       6.110
# 6   INRZeroCurve_175yr  INRZeroCurve_200yr       5.190       5.776
# 7   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 8   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 9   INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 10  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 11  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 12  INRZeroCurve_200yr  INRZeroCurve_225yr       5.776       5.776
# 13  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 14  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 15     INRZeroCurve_1m   INRZeroCurve_025m       4.950       5.040
# 16   INRZeroCurve_050m   INRZeroCurve_075m       5.170       5.190
#
# [17 rows x 37 columns]

# %%
# Interpolated rates

# %%
def interpolate_values(df):

    numerator1 = (df['upper_rates'] - df['lower_rates'])
    numerator2 = (df['residual_maturity_expected'] - df['lower_maturity'])
    numerator = numerator1*numerator2
    denominator = (df['upper_maturity'] - df['lower_maturity'])
    interpolate_col = df['lower_rates'] + (numerator/denominator)
    return interpolate_col

# %%
tx_bond_new['Interpolated_rates'] = tx_bond_new.apply(lambda x: x['upper_rates'] if x['upper_tenor_key'] == x['lower_tenor_key'] else interpolate_values(x), axis=1)

# %%
tx_bond_new
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... intbasis  \
# 0       4000             C           100000         100  ...        1
# 1      12750             C           150000         100  ...        2
# 2       5000             C           200000         100  ...        1
# 3       4000             C           100000         100  ...        1
# 4       5000             C           200000         100  ...        1
# 5       4000             C           100000         100  ...        1
# 6       4000             C           100000         100  ...        1
# 7       4000             C           100000         100  ...        1
# 8     100000             P           100000         100  ...        1
# 9      12750             C           150000         100  ...        2
# 10      5000             C           200000         100  ...        1
# 11    200000             P           200000         100  ...        1
# 12     12750             C           150000         100  ...        2
# 13     12750             C           150000         100  ...        2
# 14    150000             P           150000         100  ...        2
# 15      5000             C           200000         100  ...        1
# 16      5000             C           200000         100  ...        1
#
#                   key     c_date   m_date_E   m_date_A     lower_tenor_key  \
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16   INRZeroCurve_025m
# 2    IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20   INRZeroCurve_025m
# 3   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 4    IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21   INRZeroCurve_075m
# 5   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 6   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 7   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 8   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 9   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15  INRZeroCurve_100yr
# 10   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 11   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 12  IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15  INRZeroCurve_200yr
# 13  IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 14  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 15   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21     INRZeroCurve_1m
# 16   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20   INRZeroCurve_050m
#
#        upper_tenor_key  lower_rates upper_rates Interpolated_rates
# 0    INRZeroCurve_050m        5.040       5.170           5.060000
# 1    INRZeroCurve_050m        5.040       5.170           5.077143
# 2    INRZeroCurve_050m        5.040       5.170           5.127143
# 3   INRZeroCurve_100yr        5.190       5.190           5.190000
# 4   INRZeroCurve_100yr        5.190       5.190           5.190000
# 5   INRZeroCurve_150yr        5.190       6.110           5.331538
# 6   INRZeroCurve_200yr        5.190       5.776           5.285543
# 7   INRZeroCurve_250yr        5.776       5.776           5.776000
# 8   INRZeroCurve_250yr        5.776       5.776           5.776000
# 9   INRZeroCurve_125yr        5.190       5.190           5.190000
# 10  INRZeroCurve_125yr        5.190       5.190           5.190000
# 11  INRZeroCurve_125yr        5.190       5.190           5.190000
# 12  INRZeroCurve_225yr        5.776       5.776           5.776000
# 13  INRZeroCurve_325yr        6.357       6.357           6.357000
# 14  INRZeroCurve_325yr        6.357       6.357           6.357000
# 15   INRZeroCurve_025m        4.950       5.040           4.993500
# 16   INRZeroCurve_075m        5.170       5.190           5.183261
#
# [17 rows x 38 columns]

# %%
##Sorting the dataframe lower_rate wise
tx_bond_new.sort_values(by=['lower_rates'])
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   NCD001  IN1520190101NCD          16806  1      INR           INR
# 2    PF001   IN1520190101PF          16803  2      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
# 5   CGS001  IN0020100015CGS          16807  3      INR           INR
# 6   CGS001  IN0020100015CGS          16807  4      INR           INR
# 3   CGS001  IN0020100015CGS          16807  2      INR           INR
# 9   NCD001  IN1520190101NCD          16806  2      INR           INR
# 10   PF001   IN1520190101PF          16803  5      INR           INR
# 11   PF001   IN1520190101PF          16803  6      INR           INR
# 4    PF001   IN1520190101PF          16803  4      INR           INR
# 7   CGS001  IN0020100015CGS          16807  5      INR           INR
# 12  NCD001  IN1520190101NCD          16806  3      INR           INR
# 8   CGS001  IN0020100015CGS          16807  6      INR           INR
# 13  NCD001  IN1520190101NCD          16806  4      INR           INR
# 14  NCD001  IN1520190101NCD          16806  5      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ... intbasis  \
# 15      5000             C           200000         100  ...        1
# 0       4000             C           100000         100  ...        1
# 1      12750             C           150000         100  ...        2
# 2       5000             C           200000         100  ...        1
# 16      5000             C           200000         100  ...        1
# 5       4000             C           100000         100  ...        1
# 6       4000             C           100000         100  ...        1
# 3       4000             C           100000         100  ...        1
# 9      12750             C           150000         100  ...        2
# 10      5000             C           200000         100  ...        1
# 11    200000             P           200000         100  ...        1
# 4       5000             C           200000         100  ...        1
# 7       4000             C           100000         100  ...        1
# 12     12750             C           150000         100  ...        2
# 8     100000             P           100000         100  ...        1
# 13     12750             C           150000         100  ...        2
# 14    150000             P           150000         100  ...        2
#
#                   key     c_date   m_date_E   m_date_A     lower_tenor_key  \
# 15   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21     INRZeroCurve_1m
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16   INRZeroCurve_025m
# 2    IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20   INRZeroCurve_025m
# 16   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20   INRZeroCurve_050m
# 5   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 6   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 3   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 9   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15  INRZeroCurve_100yr
# 10   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 11   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 4    IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21   INRZeroCurve_075m
# 7   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 12  IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15  INRZeroCurve_200yr
# 8   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 13  IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 14  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
#
#        upper_tenor_key  lower_rates upper_rates Interpolated_rates
# 15   INRZeroCurve_025m        4.950       5.040           4.993500
# 0    INRZeroCurve_050m        5.040       5.170           5.060000
# 1    INRZeroCurve_050m        5.040       5.170           5.077143
# 2    INRZeroCurve_050m        5.040       5.170           5.127143
# 16   INRZeroCurve_075m        5.170       5.190           5.183261
# 5   INRZeroCurve_150yr        5.190       6.110           5.331538
# 6   INRZeroCurve_200yr        5.190       5.776           5.285543
# 3   INRZeroCurve_100yr        5.190       5.190           5.190000
# 9   INRZeroCurve_125yr        5.190       5.190           5.190000
# 10  INRZeroCurve_125yr        5.190       5.190           5.190000
# 11  INRZeroCurve_125yr        5.190       5.190           5.190000
# 4   INRZeroCurve_100yr        5.190       5.190           5.190000
# 7   INRZeroCurve_250yr        5.776       5.776           5.776000
# 12  INRZeroCurve_225yr        5.776       5.776           5.776000
# 8   INRZeroCurve_250yr        5.776       5.776           5.776000
# 13  INRZeroCurve_325yr        6.357       6.357           6.357000
# 14  INRZeroCurve_325yr        6.357       6.357           6.357000
#
# [17 rows x 38 columns]

# %% [markdown]
# ### SPREADs

# %%
spreads= getData(path7)
spreads
# Out:
#             date        instrument      rate  rate_stressed
# 0     2019-12-31   IN1520190101NCD  5.443980       5.443980
# 1     2019-12-30   IN1520190101NCD  5.273412       5.273412
# 2     2019-12-27   IN1520190101NCD  5.299568       5.299568
# 3     2019-12-26   IN1520190101NCD  5.290016       5.290016
# 4     2019-12-24   IN1520190101NCD  5.510400       5.510400
# ...          ...               ...       ...            ...
# 1501  2018-12-26  INE134E08925PSUT  0.949293       0.949293
# 1502  2018-12-24  INE134E08925PSUT  0.949293       0.949293
# 1503  2018-12-21  INE134E08925PSUT  0.949293       0.949293
# 1504  2018-12-20  INE134E08925PSUT  0.949293       0.949293
# 1505  2018-12-19  INE134E08925PSUT  0.949293       0.949293
#
# [1506 rows x 4 columns]

# %%
##Dropping duplicates
spread_rates = (spreads.drop_duplicates(['instrument']))
spread_rates.columns= spread_rates.columns.str.lower() ##Column names to lower case
spread_rates.head()
# Out:
#             date         instrument      rate  rate_stressed
# 0     2019-12-31    IN1520190101NCD  5.443980       5.443980
# 251   2019-12-31     IN1520190101PF  1.123651       1.123651
# 502   2019-12-31    IN1520190101RPF  1.041761       1.041761
# 753   2019-12-31     INE036D08015SD  3.329692       3.329692
# 1004  2019-12-31  INE095H07014PSUTF  4.649538       4.649538

# %%
##Renaming rates to spread_rates
spread_rates =  spread_rates.rename(columns = {'rate':'spread_rates'})
spread_rates.head()
# Out:
#             date         instrument  spread_rates  rate_stressed
# 0     2019-12-31    IN1520190101NCD      5.443980       5.443980
# 251   2019-12-31     IN1520190101PF      1.123651       1.123651
# 502   2019-12-31    IN1520190101RPF      1.041761       1.041761
# 753   2019-12-31     INE036D08015SD      3.329692       3.329692
# 1004  2019-12-31  INE095H07014PSUTF      4.649538       4.649538

# %%
s_rate_df = spread_rates[['instrument', 'spread_rates']].reset_index(drop=True)

# %%
s_rate_df
# Out:
#           instrument  spread_rates
# 0    IN1520190101NCD      5.443980
# 1     IN1520190101PF      1.123651
# 2    IN1520190101RPF      1.041761
# 3     INE036D08015SD      3.329692
# 4  INE095H07014PSUTF      4.649538
# 5   INE134E08925PSUT      0.602718

# %%
tx_bond_revamp = tx_bond_new.merge(s_rate_df, on ='instrument', how='left',sort = True)

# %%
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1       4000             C           100000         100  ...
# 2       4000             C           100000         100  ...
# 3       4000             C           100000         100  ...
# 4       4000             C           100000         100  ...
# 5     100000             P           100000         100  ...
# 6      12750             C           150000         100  ...
# 7      12750             C           150000         100  ...
# 8      12750             C           150000         100  ...
# 9      12750             C           150000         100  ...
# 10    150000             P           150000         100  ...
# 11      5000             C           200000         100  ...
# 12      5000             C           200000         100  ...
# 13      5000             C           200000         100  ...
# 14    200000             P           200000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#                   key     c_date   m_date_E   m_date_A     lower_tenor_key  \
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 2   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 3   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 4   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 5   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 6   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16   INRZeroCurve_025m
# 7   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15  INRZeroCurve_100yr
# 8   IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15  INRZeroCurve_200yr
# 9   IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 10  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 11   IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20   INRZeroCurve_025m
# 12   IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21   INRZeroCurve_075m
# 13   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 14   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 15   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21     INRZeroCurve_1m
# 16   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20   INRZeroCurve_050m
#
#        upper_tenor_key  lower_rates  upper_rates Interpolated_rates  \
# 0    INRZeroCurve_050m        5.040        5.170           5.060000
# 1   INRZeroCurve_100yr        5.190        5.190           5.190000
# 2   INRZeroCurve_150yr        5.190        6.110           5.331538
# 3   INRZeroCurve_200yr        5.190        5.776           5.285543
# 4   INRZeroCurve_250yr        5.776        5.776           5.776000
# 5   INRZeroCurve_250yr        5.776        5.776           5.776000
# 6    INRZeroCurve_050m        5.040        5.170           5.077143
# 7   INRZeroCurve_125yr        5.190        5.190           5.190000
# 8   INRZeroCurve_225yr        5.776        5.776           5.776000
# 9   INRZeroCurve_325yr        6.357        6.357           6.357000
# 10  INRZeroCurve_325yr        6.357        6.357           6.357000
# 11   INRZeroCurve_050m        5.040        5.170           5.127143
# 12  INRZeroCurve_100yr        5.190        5.190           5.190000
# 13  INRZeroCurve_125yr        5.190        5.190           5.190000
# 14  INRZeroCurve_125yr        5.190        5.190           5.190000
# 15   INRZeroCurve_025m        4.950        5.040           4.993500
# 16   INRZeroCurve_075m        5.170        5.190           5.183261
#
#    spread_rates
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6      5.443980
# 7      5.443980
# 8      5.443980
# 9      5.443980
# 10     5.443980
# 11     1.123651
# 12     1.123651
# 13     1.123651
# 14     1.123651
# 15     1.123651
# 16     1.123651
#
# [17 rows x 39 columns]

# %%
#Replacing NAN's with 0's
tx_bond_revamp['spread_rates'] = tx_bond_revamp['spread_rates'].fillna(0)
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1       4000             C           100000         100  ...
# 2       4000             C           100000         100  ...
# 3       4000             C           100000         100  ...
# 4       4000             C           100000         100  ...
# 5     100000             P           100000         100  ...
# 6      12750             C           150000         100  ...
# 7      12750             C           150000         100  ...
# 8      12750             C           150000         100  ...
# 9      12750             C           150000         100  ...
# 10    150000             P           150000         100  ...
# 11      5000             C           200000         100  ...
# 12      5000             C           200000         100  ...
# 13      5000             C           200000         100  ...
# 14    200000             P           200000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#                   key     c_date   m_date_E   m_date_A     lower_tenor_key  \
# 0   IN0020100015CGS_1 2020-04-20 2020-08-03 2020-08-03   INRZeroCurve_025m
# 1   IN0020100015CGS_2 2020-04-20 2021-02-03 2021-02-03   INRZeroCurve_075m
# 2   IN0020100015CGS_3 2020-04-20 2021-08-03 2021-08-03  INRZeroCurve_125yr
# 3   IN0020100015CGS_4 2020-04-20 2022-02-03 2022-02-03  INRZeroCurve_175yr
# 4   IN0020100015CGS_5 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 5   IN0020100015CGS_6 2020-04-20 2022-08-03 2022-08-03  INRZeroCurve_225yr
# 6   IN1520190101NCD_1 2020-04-20 2020-08-15 2020-08-16   INRZeroCurve_025m
# 7   IN1520190101NCD_2 2020-04-20 2021-08-15 2021-08-15  INRZeroCurve_100yr
# 8   IN1520190101NCD_3 2020-04-20 2022-08-15 2022-08-15  INRZeroCurve_200yr
# 9   IN1520190101NCD_4 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 10  IN1520190101NCD_5 2020-04-20 2023-08-15 2023-08-15  INRZeroCurve_300yr
# 11   IN1520190101PF_2 2020-04-20 2020-09-19 2020-09-20   INRZeroCurve_025m
# 12   IN1520190101PF_4 2020-04-20 2021-03-19 2021-03-21   INRZeroCurve_075m
# 13   IN1520190101PF_5 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 14   IN1520190101PF_6 2020-04-20 2021-06-19 2021-06-20  INRZeroCurve_100yr
# 15   IN1520190101PF_1 2020-04-20 2020-06-19 2020-06-21     INRZeroCurve_1m
# 16   IN1520190101PF_3 2020-04-20 2020-12-19 2020-12-20   INRZeroCurve_050m
#
#        upper_tenor_key  lower_rates  upper_rates Interpolated_rates  \
# 0    INRZeroCurve_050m        5.040        5.170           5.060000
# 1   INRZeroCurve_100yr        5.190        5.190           5.190000
# 2   INRZeroCurve_150yr        5.190        6.110           5.331538
# 3   INRZeroCurve_200yr        5.190        5.776           5.285543
# 4   INRZeroCurve_250yr        5.776        5.776           5.776000
# 5   INRZeroCurve_250yr        5.776        5.776           5.776000
# 6    INRZeroCurve_050m        5.040        5.170           5.077143
# 7   INRZeroCurve_125yr        5.190        5.190           5.190000
# 8   INRZeroCurve_225yr        5.776        5.776           5.776000
# 9   INRZeroCurve_325yr        6.357        6.357           6.357000
# 10  INRZeroCurve_325yr        6.357        6.357           6.357000
# 11   INRZeroCurve_050m        5.040        5.170           5.127143
# 12  INRZeroCurve_100yr        5.190        5.190           5.190000
# 13  INRZeroCurve_125yr        5.190        5.190           5.190000
# 14  INRZeroCurve_125yr        5.190        5.190           5.190000
# 15   INRZeroCurve_025m        4.950        5.040           4.993500
# 16   INRZeroCurve_075m        5.170        5.190           5.183261
#
#    spread_rates
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.000000
# 6      5.443980
# 7      5.443980
# 8      5.443980
# 9      5.443980
# 10     5.443980
# 11     1.123651
# 12     1.123651
# 13     1.123651
# 14     1.123651
# 15     1.123651
# 16     1.123651
#
# [17 rows x 39 columns]

# %%
tx_bond_revamp.shape
# Out:
# (17, 39)

# %%
tx_bond_revamp.columns
# Out:
# Index(['id', 'instrument', 'instrument_id', 'k', 'currency', 'currency_base',
#        'Cashflow', 'Cashflow_Type', 'Maturity_Amount', 'Face_value', 'curve',
#        'current_date', 'Cash_flow_Dates', 'holiday', 'Actual_Cash_flow_date',
#        'maturity_date', 'residual_maturity_expected',
#        'residual_maturity_Actual', 'lower_tenor', 'upper_tenor',
#        'lower_tenor_val', 'upper_tenor_val', 'lower_maturity',
#        'upper_maturity', 'split_curve', 'accounting_book',
#        'accounting_portfolio', 'mark_up_value', 'intbasis', 'key', 'c_date',
#        'm_date_E', 'm_date_A', 'lower_tenor_key', 'upper_tenor_key',
#        'lower_rates', 'upper_rates', 'Interpolated_rates', 'spread_rates'],
#       dtype='object')

# %%
#YTM(Yield to Maturity)
tx_bond_revamp['YTM']= tx_bond_revamp['Interpolated_rates'] + tx_bond_revamp['spread_rates'] + tx_bond_revamp['mark_up_value']

# %%
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...     c_date  \
# 0       4000             C           100000         100  ... 2020-04-20
# 1       4000             C           100000         100  ... 2020-04-20
# 2       4000             C           100000         100  ... 2020-04-20
# 3       4000             C           100000         100  ... 2020-04-20
# 4       4000             C           100000         100  ... 2020-04-20
# 5     100000             P           100000         100  ... 2020-04-20
# 6      12750             C           150000         100  ... 2020-04-20
# 7      12750             C           150000         100  ... 2020-04-20
# 8      12750             C           150000         100  ... 2020-04-20
# 9      12750             C           150000         100  ... 2020-04-20
# 10    150000             P           150000         100  ... 2020-04-20
# 11      5000             C           200000         100  ... 2020-04-20
# 12      5000             C           200000         100  ... 2020-04-20
# 13      5000             C           200000         100  ... 2020-04-20
# 14    200000             P           200000         100  ... 2020-04-20
# 15      5000             C           200000         100  ... 2020-04-20
# 16      5000             C           200000         100  ... 2020-04-20
#
#      m_date_E   m_date_A     lower_tenor_key     upper_tenor_key lower_rates  \
# 0  2020-08-03 2020-08-03   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 1  2021-02-03 2021-02-03   INRZeroCurve_075m  INRZeroCurve_100yr       5.190
# 2  2021-08-03 2021-08-03  INRZeroCurve_125yr  INRZeroCurve_150yr       5.190
# 3  2022-02-03 2022-02-03  INRZeroCurve_175yr  INRZeroCurve_200yr       5.190
# 4  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776
# 5  2022-08-03 2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776
# 6  2020-08-15 2020-08-16   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 7  2021-08-15 2021-08-15  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 8  2022-08-15 2022-08-15  INRZeroCurve_200yr  INRZeroCurve_225yr       5.776
# 9  2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357
# 10 2023-08-15 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357
# 11 2020-09-19 2020-09-20   INRZeroCurve_025m   INRZeroCurve_050m       5.040
# 12 2021-03-19 2021-03-21   INRZeroCurve_075m  INRZeroCurve_100yr       5.190
# 13 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 14 2021-06-19 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190
# 15 2020-06-19 2020-06-21     INRZeroCurve_1m   INRZeroCurve_025m       4.950
# 16 2020-12-19 2020-12-20   INRZeroCurve_050m   INRZeroCurve_075m       5.170
#
#     upper_rates  Interpolated_rates spread_rates        YTM
# 0         5.170            5.060000     0.000000   5.060000
# 1         5.190            5.190000     0.000000   5.190000
# 2         6.110            5.331538     0.000000   5.331538
# 3         5.776            5.285543     0.000000   5.285543
# 4         5.776            5.776000     0.000000   5.776000
# 5         5.776            5.776000     0.000000   5.776000
# 6         5.170            5.077143     5.443980  10.521123
# 7         5.190            5.190000     5.443980  10.633980
# 8         5.776            5.776000     5.443980  11.219980
# 9         6.357            6.357000     5.443980  11.800980
# 10        6.357            6.357000     5.443980  11.800980
# 11        5.170            5.127143     1.123651   6.250794
# 12        5.190            5.190000     1.123651   6.313651
# 13        5.190            5.190000     1.123651   6.313651
# 14        5.190            5.190000     1.123651   6.313651
# 15        5.040            4.993500     1.123651   6.117151
# 16        5.190            5.183261     1.123651   6.306912
#
# [17 rows x 40 columns]

# %%
#result = tx_bond_revamp.dtypes
#result

# %%
tx_bond_revamp['maturity_period_E'] = (tx_bond_revamp['m_date_E'] - tx_bond_revamp['c_date']).dt.days
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...   m_date_E  \
# 0       4000             C           100000         100  ... 2020-08-03
# 1       4000             C           100000         100  ... 2021-02-03
# 2       4000             C           100000         100  ... 2021-08-03
# 3       4000             C           100000         100  ... 2022-02-03
# 4       4000             C           100000         100  ... 2022-08-03
# 5     100000             P           100000         100  ... 2022-08-03
# 6      12750             C           150000         100  ... 2020-08-15
# 7      12750             C           150000         100  ... 2021-08-15
# 8      12750             C           150000         100  ... 2022-08-15
# 9      12750             C           150000         100  ... 2023-08-15
# 10    150000             P           150000         100  ... 2023-08-15
# 11      5000             C           200000         100  ... 2020-09-19
# 12      5000             C           200000         100  ... 2021-03-19
# 13      5000             C           200000         100  ... 2021-06-19
# 14    200000             P           200000         100  ... 2021-06-19
# 15      5000             C           200000         100  ... 2020-06-19
# 16      5000             C           200000         100  ... 2020-12-19
#
#      m_date_A     lower_tenor_key     upper_tenor_key lower_rates upper_rates  \
# 0  2020-08-03   INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 1  2021-02-03   INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 2  2021-08-03  INRZeroCurve_125yr  INRZeroCurve_150yr       5.190       6.110
# 3  2022-02-03  INRZeroCurve_175yr  INRZeroCurve_200yr       5.190       5.776
# 4  2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 5  2022-08-03  INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 6  2020-08-16   INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 7  2021-08-15  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 8  2022-08-15  INRZeroCurve_200yr  INRZeroCurve_225yr       5.776       5.776
# 9  2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 10 2023-08-15  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 11 2020-09-20   INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 12 2021-03-21   INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 13 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 14 2021-06-20  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 15 2020-06-21     INRZeroCurve_1m   INRZeroCurve_025m       4.950       5.040
# 16 2020-12-20   INRZeroCurve_050m   INRZeroCurve_075m       5.170       5.190
#
#     Interpolated_rates  spread_rates        YTM maturity_period_E
# 0             5.060000      0.000000   5.060000               105
# 1             5.190000      0.000000   5.190000               289
# 2             5.331538      0.000000   5.331538               470
# 3             5.285543      0.000000   5.285543               654
# 4             5.776000      0.000000   5.776000               835
# 5             5.776000      0.000000   5.776000               835
# 6             5.077143      5.443980  10.521123               117
# 7             5.190000      5.443980  10.633980               482
# 8             5.776000      5.443980  11.219980               847
# 9             6.357000      5.443980  11.800980              1212
# 10            6.357000      5.443980  11.800980              1212
# 11            5.127143      1.123651   6.250794               152
# 12            5.190000      1.123651   6.313651               333
# 13            5.190000      1.123651   6.313651               425
# 14            5.190000      1.123651   6.313651               425
# 15            4.993500      1.123651   6.117151                60
# 16            5.183261      1.123651   6.306912               243
#
# [17 rows x 41 columns]

# %%
tx_bond_revamp['maturity_period_A'] = (tx_bond_revamp['m_date_A'] - tx_bond_revamp['c_date']).dt.days
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...   m_date_A  \
# 0       4000             C           100000         100  ... 2020-08-03
# 1       4000             C           100000         100  ... 2021-02-03
# 2       4000             C           100000         100  ... 2021-08-03
# 3       4000             C           100000         100  ... 2022-02-03
# 4       4000             C           100000         100  ... 2022-08-03
# 5     100000             P           100000         100  ... 2022-08-03
# 6      12750             C           150000         100  ... 2020-08-16
# 7      12750             C           150000         100  ... 2021-08-15
# 8      12750             C           150000         100  ... 2022-08-15
# 9      12750             C           150000         100  ... 2023-08-15
# 10    150000             P           150000         100  ... 2023-08-15
# 11      5000             C           200000         100  ... 2020-09-20
# 12      5000             C           200000         100  ... 2021-03-21
# 13      5000             C           200000         100  ... 2021-06-20
# 14    200000             P           200000         100  ... 2021-06-20
# 15      5000             C           200000         100  ... 2020-06-21
# 16      5000             C           200000         100  ... 2020-12-20
#
#        lower_tenor_key     upper_tenor_key lower_rates upper_rates  \
# 0    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 1    INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 2   INRZeroCurve_125yr  INRZeroCurve_150yr       5.190       6.110
# 3   INRZeroCurve_175yr  INRZeroCurve_200yr       5.190       5.776
# 4   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 5   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 6    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 7   INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 8   INRZeroCurve_200yr  INRZeroCurve_225yr       5.776       5.776
# 9   INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 10  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 11   INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 12   INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 13  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 14  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 15     INRZeroCurve_1m   INRZeroCurve_025m       4.950       5.040
# 16   INRZeroCurve_050m   INRZeroCurve_075m       5.170       5.190
#
#    Interpolated_rates  spread_rates        YTM maturity_period_E  \
# 0            5.060000      0.000000   5.060000               105
# 1            5.190000      0.000000   5.190000               289
# 2            5.331538      0.000000   5.331538               470
# 3            5.285543      0.000000   5.285543               654
# 4            5.776000      0.000000   5.776000               835
# 5            5.776000      0.000000   5.776000               835
# 6            5.077143      5.443980  10.521123               117
# 7            5.190000      5.443980  10.633980               482
# 8            5.776000      5.443980  11.219980               847
# 9            6.357000      5.443980  11.800980              1212
# 10           6.357000      5.443980  11.800980              1212
# 11           5.127143      1.123651   6.250794               152
# 12           5.190000      1.123651   6.313651               333
# 13           5.190000      1.123651   6.313651               425
# 14           5.190000      1.123651   6.313651               425
# 15           4.993500      1.123651   6.117151                60
# 16           5.183261      1.123651   6.306912               243
#
#    maturity_period_A
# 0                105
# 1                289
# 2                470
# 3                654
# 4                835
# 5                835
# 6                118
# 7                482
# 8                847
# 9               1212
# 10              1212
# 11               153
# 12               335
# 13               426
# 14               426
# 15                62
# 16               244
#
# [17 rows x 42 columns]

# %%
##Condition

# %%
tx_bond_revamp['no_of_days_in_a_year'] = ''
for i in range (len(tx_bond_revamp)):

  
  if  tx_bond_revamp['intbasis'][i] == 0:
        tx_bond_revamp['no_of_days_in_a_year'][i] = 360
  
  elif tx_bond_revamp['intbasis'][i] == 1: 
        tx_bond_revamp['no_of_days_in_a_year'][i] = 365  
  
  elif tx_bond_revamp['intbasis'][i] == 2: 
        tx_bond_revamp['no_of_days_in_a_year'][i] = 360 
  
  elif tx_bond_revamp['intbasis'][i] == 3: 
        tx_bond_revamp['no_of_days_in_a_year'][i] = 365 
  
  elif tx_bond_revamp['intbasis'][i] == 4: 
        tx_bond_revamp['no_of_days_in_a_year'][i] = 360
   
  else:
        pass
# Out:
# /tmp/ipykernel_102/2565406497.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tx_bond_revamp['no_of_days_in_a_year'][i] = 365
# /tmp/ipykernel_102/2565406497.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tx_bond_revamp['no_of_days_in_a_year'][i] = 360

# %%
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1       4000             C           100000         100  ...
# 2       4000             C           100000         100  ...
# 3       4000             C           100000         100  ...
# 4       4000             C           100000         100  ...
# 5     100000             P           100000         100  ...
# 6      12750             C           150000         100  ...
# 7      12750             C           150000         100  ...
# 8      12750             C           150000         100  ...
# 9      12750             C           150000         100  ...
# 10    150000             P           150000         100  ...
# 11      5000             C           200000         100  ...
# 12      5000             C           200000         100  ...
# 13      5000             C           200000         100  ...
# 14    200000             P           200000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#        lower_tenor_key     upper_tenor_key lower_rates upper_rates  \
# 0    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 1    INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 2   INRZeroCurve_125yr  INRZeroCurve_150yr       5.190       6.110
# 3   INRZeroCurve_175yr  INRZeroCurve_200yr       5.190       5.776
# 4   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 5   INRZeroCurve_225yr  INRZeroCurve_250yr       5.776       5.776
# 6    INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 7   INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 8   INRZeroCurve_200yr  INRZeroCurve_225yr       5.776       5.776
# 9   INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 10  INRZeroCurve_300yr  INRZeroCurve_325yr       6.357       6.357
# 11   INRZeroCurve_025m   INRZeroCurve_050m       5.040       5.170
# 12   INRZeroCurve_075m  INRZeroCurve_100yr       5.190       5.190
# 13  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 14  INRZeroCurve_100yr  INRZeroCurve_125yr       5.190       5.190
# 15     INRZeroCurve_1m   INRZeroCurve_025m       4.950       5.040
# 16   INRZeroCurve_050m   INRZeroCurve_075m       5.170       5.190
#
#    Interpolated_rates spread_rates        YTM  maturity_period_E  \
# 0            5.060000     0.000000   5.060000                105
# 1            5.190000     0.000000   5.190000                289
# 2            5.331538     0.000000   5.331538                470
# 3            5.285543     0.000000   5.285543                654
# 4            5.776000     0.000000   5.776000                835
# 5            5.776000     0.000000   5.776000                835
# 6            5.077143     5.443980  10.521123                117
# 7            5.190000     5.443980  10.633980                482
# 8            5.776000     5.443980  11.219980                847
# 9            6.357000     5.443980  11.800980               1212
# 10           6.357000     5.443980  11.800980               1212
# 11           5.127143     1.123651   6.250794                152
# 12           5.190000     1.123651   6.313651                333
# 13           5.190000     1.123651   6.313651                425
# 14           5.190000     1.123651   6.313651                425
# 15           4.993500     1.123651   6.117151                 60
# 16           5.183261     1.123651   6.306912                243
#
#    maturity_period_A no_of_days_in_a_year
# 0                105                  365
# 1                289                  365
# 2                470                  365
# 3                654                  365
# 4                835                  365
# 5                835                  365
# 6                118                  360
# 7                482                  360
# 8                847                  360
# 9               1212                  360
# 10              1212                  360
# 11               153                  365
# 12               335                  365
# 13               426                  365
# 14               426                  365
# 15                62                  365
# 16               244                  365
#
# [17 rows x 43 columns]

# %%
#cashflow_mtm
tx_bond_revamp['cashflow_mtm'] = tx_bond_revamp['Cashflow'] / ((1+(tx_bond_revamp['YTM']/100))**(tx_bond_revamp['residual_maturity_Actual']/tx_bond_revamp['no_of_days_in_a_year']))

# %%
tx_bond_revamp
# Out:
#         id       instrument  instrument_id  k currency currency_base  \
# 0   CGS001  IN0020100015CGS          16807  1      INR           INR
# 1   CGS001  IN0020100015CGS          16807  2      INR           INR
# 2   CGS001  IN0020100015CGS          16807  3      INR           INR
# 3   CGS001  IN0020100015CGS          16807  4      INR           INR
# 4   CGS001  IN0020100015CGS          16807  5      INR           INR
# 5   CGS001  IN0020100015CGS          16807  6      INR           INR
# 6   NCD001  IN1520190101NCD          16806  1      INR           INR
# 7   NCD001  IN1520190101NCD          16806  2      INR           INR
# 8   NCD001  IN1520190101NCD          16806  3      INR           INR
# 9   NCD001  IN1520190101NCD          16806  4      INR           INR
# 10  NCD001  IN1520190101NCD          16806  5      INR           INR
# 11   PF001   IN1520190101PF          16803  2      INR           INR
# 12   PF001   IN1520190101PF          16803  4      INR           INR
# 13   PF001   IN1520190101PF          16803  5      INR           INR
# 14   PF001   IN1520190101PF          16803  6      INR           INR
# 15   PF001   IN1520190101PF          16803  1      INR           INR
# 16   PF001   IN1520190101PF          16803  3      INR           INR
#
#     Cashflow Cashflow_Type  Maturity_Amount  Face_value  ...  \
# 0       4000             C           100000         100  ...
# 1       4000             C           100000         100  ...
# 2       4000             C           100000         100  ...
# 3       4000             C           100000         100  ...
# 4       4000             C           100000         100  ...
# 5     100000             P           100000         100  ...
# 6      12750             C           150000         100  ...
# 7      12750             C           150000         100  ...
# 8      12750             C           150000         100  ...
# 9      12750             C           150000         100  ...
# 10    150000             P           150000         100  ...
# 11      5000             C           200000         100  ...
# 12      5000             C           200000         100  ...
# 13      5000             C           200000         100  ...
# 14    200000             P           200000         100  ...
# 15      5000             C           200000         100  ...
# 16      5000             C           200000         100  ...
#
#        upper_tenor_key lower_rates upper_rates Interpolated_rates  \
# 0    INRZeroCurve_050m       5.040       5.170           5.060000
# 1   INRZeroCurve_100yr       5.190       5.190           5.190000
# 2   INRZeroCurve_150yr       5.190       6.110           5.331538
# 3   INRZeroCurve_200yr       5.190       5.776           5.285543
# 4   INRZeroCurve_250yr       5.776       5.776           5.776000
# 5   INRZeroCurve_250yr       5.776       5.776           5.776000
# 6    INRZeroCurve_050m       5.040       5.170           5.077143
# 7   INRZeroCurve_125yr       5.190       5.190           5.190000
# 8   INRZeroCurve_225yr       5.776       5.776           5.776000
# 9   INRZeroCurve_325yr       6.357       6.357           6.357000
# 10  INRZeroCurve_325yr       6.357       6.357           6.357000
# 11   INRZeroCurve_050m       5.040       5.170           5.127143
# 12  INRZeroCurve_100yr       5.190       5.190           5.190000
# 13  INRZeroCurve_125yr       5.190       5.190           5.190000
# 14  INRZeroCurve_125yr       5.190       5.190           5.190000
# 15   INRZeroCurve_025m       4.950       5.040           4.993500
# 16   INRZeroCurve_075m       5.170       5.190           5.183261
#
#    spread_rates        YTM  maturity_period_E  maturity_period_A  \
# 0      0.000000   5.060000                105                105
# 1      0.000000   5.190000                289                289
# 2      0.000000   5.331538                470                470
# 3      0.000000   5.285543                654                654
# 4      0.000000   5.776000                835                835
# 5      0.000000   5.776000                835                835
# 6      5.443980  10.521123                117                118
# 7      5.443980  10.633980                482                482
# 8      5.443980  11.219980                847                847
# 9      5.443980  11.800980               1212               1212
# 10     5.443980  11.800980               1212               1212
# 11     1.123651   6.250794                152                153
# 12     1.123651   6.313651                333                335
# 13     1.123651   6.313651                425                426
# 14     1.123651   6.313651                425                426
# 15     1.123651   6.117151                 60                 62
# 16     1.123651   6.306912                243                244
#
#    no_of_days_in_a_year   cashflow_mtm
# 0                   365    3943.601917
# 1                   365    3842.917306
# 2                   365    3741.210574
# 3                   365    3647.372389
# 4                   365    3517.792617
# 5                   365    87944.81543
# 6                   360   12338.710772
# 7                   360   11136.489436
# 8                   360    9927.783236
# 9                   360    8758.101185
# 10                  360  103036.484524
# 11                  365    4874.523069
# 12                  365    4726.790688
# 13                  365    4655.189072
# 14                  365  186207.562886
# 15                  365    4949.826628
# 16                  365    4799.697001
#
# [17 rows x 44 columns]

# %%
tx_bond_revamp.columns
# Out:
# Index(['id', 'instrument', 'instrument_id', 'k', 'currency', 'currency_base',
#        'Cashflow', 'Cashflow_Type', 'Maturity_Amount', 'Face_value', 'curve',
#        'current_date', 'Cash_flow_Dates', 'holiday', 'Actual_Cash_flow_date',
#        'maturity_date', 'residual_maturity_expected',
#        'residual_maturity_Actual', 'lower_tenor', 'upper_tenor',
#        'lower_tenor_val', 'upper_tenor_val', 'lower_maturity',
#        'upper_maturity', 'split_curve', 'accounting_book',
#        'accounting_portfolio', 'mark_up_value', 'intbasis', 'key', 'c_date',
#        'm_date_E', 'm_date_A', 'lower_tenor_key', 'upper_tenor_key',
#        'lower_rates', 'upper_rates', 'Interpolated_rates', 'spread_rates',
#        'YTM', 'maturity_period_E', 'maturity_period_A', 'no_of_days_in_a_year',
#        'cashflow_mtm'],
#       dtype='object')

# %%
##MTM

# %%
df2 = tx_bond_revamp.groupby('id')['cashflow_mtm'].sum()
mtm = list(df2)
mtm = [round(item, 0) for item in mtm]
mtm = pd.DataFrame(mtm)
mtm
# Out:
#           0
# 0  106638.0
# 1  145198.0
# 2  210214.0

# %%
def get_mtm_bc(tx_eq):
    
    res_df = list()
    for k, h in tx_eq.groupby('id'):
        result = {'idx':h["id"].iloc[0] , "env":k,"instrument":h["instrument"].iloc[0] ,"currency":h["currency"].iloc[0] ,"currency_base":h["currency_base"].iloc[0], "face_value":h["Face_value"].iloc[0], "maturity_amount":h["Maturity_Amount"].iloc[0]}
        res_df.append(result)
        #res_df = pd.DataFrame(res_df)

    return res_df

# %%
get_mtm_bc(tx_bond_revamp)
# Out:
# [{'idx': 'CGS001',
#   'env': 'CGS001',
#   'instrument': 'IN0020100015CGS',
#   'currency': 'INR',
#   'currency_base': 'INR',
#   'face_value': 100,
#   'maturity_amount': 100000},
#  {'idx': 'NCD001',
#   'env': 'NCD001',
#   'instrument': 'IN1520190101NCD',
#   'currency': 'INR',
#   'currency_base': 'INR',
#   'face_value': 100,
#   'maturity_amount': 150000},
#  {'idx': 'PF001',
#   'env': 'PF001',
#   'instrument': 'IN1520190101PF',
#   'currency': 'INR',
#   'currency_base': 'INR',
#   'face_value': 100,
#   'maturity_amount': 200000}]

# %%
#, "bondwise_current_mtm":mtm[0]
red = get_mtm_bc(tx_bond_revamp)
res = pd.DataFrame(red)
res
# Out:
#       idx     env       instrument currency currency_base  face_value  \
# 0  CGS001  CGS001  IN0020100015CGS      INR           INR         100
# 1  NCD001  NCD001  IN1520190101NCD      INR           INR         100
# 2   PF001   PF001   IN1520190101PF      INR           INR         100
#
#    maturity_amount
# 0           100000
# 1           150000
# 2           200000

# %%
#renaming the column for mtm
mtm.rename(columns = {0:'bondwise_current_mtm'}, inplace = True)
mtm = mtm.reset_index(drop = True)
mtm
# Out:
#    bondwise_current_mtm
# 0              106638.0
# 1              145198.0
# 2              210214.0

# %%
#concatenating res dataframe and mtm dataframe 
result_new = pd.concat([res, mtm], axis = 1)
result_new
# Out:
#       idx     env       instrument currency currency_base  face_value  \
# 0  CGS001  CGS001  IN0020100015CGS      INR           INR         100
# 1  NCD001  NCD001  IN1520190101NCD      INR           INR         100
# 2   PF001   PF001   IN1520190101PF      INR           INR         100
#
#    maturity_amount  bondwise_current_mtm
# 0           100000              106638.0
# 1           150000              145198.0
# 2           200000              210214.0

# %%
#Calibrating price
result_new['price'] = (result_new['bondwise_current_mtm']*result_new['face_value'])/result_new['maturity_amount']
result_new
# Out:
#       idx     env       instrument currency currency_base  face_value  \
# 0  CGS001  CGS001  IN0020100015CGS      INR           INR         100
# 1  NCD001  NCD001  IN1520190101NCD      INR           INR         100
# 2   PF001   PF001   IN1520190101PF      INR           INR         100
#
#    maturity_amount  bondwise_current_mtm       price
# 0           100000              106638.0  106.638000
# 1           150000              145198.0   96.798667
# 2           200000              210214.0  105.107000

# %% [markdown]
# ### All MTMS

# %%
interpolated_curve_rate = np.empty((n+1,1))
lW_rate1 = np.empty((n+1,3))
up_rate1 = np.empty((n+1,3))

# %%
interpolated_curve_rate = pd.DataFrame()
lw_rate1 = pd.DataFrame()
up_rate1 = pd.DataFrame()
for i in range(0,len(tx_bond_revamp)):
            a = tx_bond_revamp.loc[i,['lower_tenor_key', 'upper_tenor_key']]

            rates = simulated_interest[simulated_interest['key'].isin(a)]
            rates = rates.loc[:, ['key','simulated rates']]
            rates = rates.set_index('key')
                ##Segregating simulations according to the instrument
            rates2 = (rates.assign(labels = rates.groupby(level = 0).cumcount())
                    .groupby([rates.index,'labels']).first()
                    .unstack('labels')
                    .sort_index(axis =1,level = 1)
                    .droplevel(1,axis = 1))

            rates2 = rates2.transpose()    
            rates2 = rates2.reset_index(drop = True)

            #rates2 =rates2[,match(a,colnames(rates2))]
            rates2['key'] = tx_bond['key'][i]
            rates2['maturity']= tx_bond_revamp['residual_maturity_expected'][i]
            rates2['lower_tenor'] = tx_bond_revamp['lower_maturity'][i]
            rates2['upper_tenor'] = tx_bond_revamp['upper_maturity'][i]
            if (rates2.iat[0,4]==rates2.iat[0,5]):
                    rates2['intepolated'] = rates2.iloc[:,0]
                    
            else :
                    rates2['intepolated'] = rates2.iloc[:,0]+((rates2.iloc[:,1]-rates2.iloc[:,0])*(rates2.iloc[:,3]-rates2.iloc[:,4]))/(rates2.iloc[:,5]-rates2.iloc[:,4])
        
            rates3=pd.DataFrame(rates2.iloc[:,-1])
            rates4=pd.DataFrame(rates2.iloc[:,0])
            rates5=pd.DataFrame(rates2.iloc[:,1])
            id=tx_bond['key'][i]
            
            rates3.columns = [rates2['key'][0]]
            rates4.columns = [id]
            rates5.columns = [id]
            interpolated_curve= pd.DataFrame(rates3)
            interpolated_curve_rate = pd.concat([interpolated_curve_rate,interpolated_curve], axis = 1)
            lw_rate1 = pd.concat([lw_rate1,rates4], axis = 1)
            up_rate1 = pd.concat([up_rate1,rates5], axis = 1)

# %%
rates

# %%
aaa = pd.DataFrame(tx_bond_revamp['instrument'].unique())
#aaa = pd.DataFrame(aaa)
##Unique instrument of spreads
zzz = pd.DataFrame(spreads['instrument'].unique())
common = aaa.merge(zzz, on=[0])
common = list(common[0].values)
spreads1 = spreads.loc[spreads['instrument'].isin(common)]

# %%
instru_count = pd.DataFrame()
if len(spreads1) == 0:
    names = list(interpolated_curve_rate.columns)
    spreads_unstk = pd.DataFrame(columns = names)   
else:
    spread_1 = spreads1.loc[:, ['instrument','rate']]
    spread_1 = spread_1.set_index('instrument')
    spreads_unstk = (spread_1.assign(labels = spread_1.groupby(level = 0).cumcount())
                    .groupby([spread_1.index,'labels']).first()
                    .unstack('labels')
                    .sort_index(axis =1,level = 1)
                    .droplevel(1,axis = 1))
    spreads_unstk = spreads_unstk.transpose()
    instru_list = list(tx_bond['instrument'].unique())
    count = list(tx_bond['instrument'].value_counts())
    #instru_count = pd.DataFrame(columns = ['instrument','k'] )
    instru_count['instrument'] = instru_list
    instru_count['k'] = count
    x = pd.DataFrame(spreads1['instrument'].unique())
    y = pd.DataFrame(instru_count['instrument'].unique())
    common1 = x.merge(y, on=[0])
    common1 = list(common1[0].values)
    freq = instru_count.loc[instru_count['instrument'].isin(common1)]
    for i in range(1, (len(freq['instrument'].unique())+1)):
        a = freq['k'][i]-1
        for j in range (0, a):
            spreads_unstk = pd.concat([spreads_unstk,spreads_unstk.iloc[:,j]], axis = 1)
        #spreads_unstk = spreads_unstk.reindex(sorted(spreads_unstk.columns), axis=1)
        
            
        #spreads_unstk = pd.concat(spreads_unstk,np.repeat(spreads_unstk.iloc[:,i],[freq['k'][i]-1]), axis = 1)  
#spreads_unstk=cbind(spreads_unstk,rep(spreads_unstk[i],freq$k[i]-1))

# %%
sp = [sorted(spreads_unstk.columns)]
sp

# %%
instru_count['instrument'] = instru_list
instru_count['k'] = count

# %%
instru_count

# %%
spreads_unstk

# %%
spreads_unstk.columns

# %%
freq

# %%
spreads_unstk

# %%
freq

# %%
spreads_unstk=cbind(spreads_unstk,rep(spreads_unstk[i],freq$k[i]-1))

# %%
len(freq['instrument'].unique())

# %%
for (i in 1:length(unique(freq$instrument))){
    spreads_unstk=cbind(spreads_unstk,rep(spreads_unstk[i],freq$k[i]-1))
  }

# %% [markdown]
# ### VAR computation for portfolio

# %%
if (decay_factor==0):
    VaR_exact_one_day = -(np.quantile(Portfolio_change_in_MTM, prob = (1 - confidence_level))
    Portfolio_change_in_MTM_sorted = sorted(Portfolio_change_in_MTM, reverse = True)
    nearby = np.floor(confidence_level * len(Portfolio_change_in_MTM))
    nearby = int(nearby)
    nearby_nxt = nearby + 1
    
    diff1 = pd.to_numeric(VaR_exact_one_day + Portfolio_change_in_mtm_sorted[nearby])
    diff2 = pd.to_numeric(- Portfolio_change_in_MTM_sorted[nearby_nxt] - VaR_exact_one_day)
                          
    if (diff1 == diff2):
        VaR_nearby_one_day = - Portfolio_change_in_MTM_sorted[nearby + 1]
    elif (diff1 < diff2):
        VaR_nearby_one_day = - Portfolio_change_in_MTM_sorted[nearby]
    else:
        VaR_nearby_one_day = - Portfolio_change_in_MTM_sorted[nearby + 1]

else:
    
    decay_weights = (1-decay_factor)* ((decay_factor ** range(0,(len(change_df['idx'].unique())-1)))/((1 - decay_factor) ** (len(change_df['idx'].unique() -1))))
    total_mtm = result.groupby('idx')[['all_mtm']].sum
    mtm_returns = []
    
    for i in range(1,(len(change_df['idx'].unique() -1))):
                   fv = total_mtm['mtm_bc'][0]
                   returns = (total_mtm['mtm_bc'][i] - fv)/fv
                   mtm_returns.append(returns) 
    
    decay_weights = pd.DataFrame(decay_weights, columns = ['decay_weights'])
    mtm_returns = pd.DataFrame(mtm_returns, columns = ['mtm_returns'])
    mtm = pd.concat([mtm_returns,decay_weights], axis = 1)
    mtm = mtm.sort_values(['mtm_returns'])
    mtm['cum_decay_weights'] = np.cumsum(mtm['decay_weights'])
    a = 1-confidence_level
    mtm1 = mtm.loc[mtm['cum_decay_weights'] < a]
    
    if (len(mtm1['cum_decay_weights'])==0):
                  VaR_exact_one_day = np.abs(- mtm['mtm_returns'][0] * total_mtm['mtm_bc'][0])

                  VaR_exact_one_day = VaR_exact_one_day

    else:
                  index = len(mtm1['cum_decay_weights'])
                                         
                  interpolated_return_exact = mtm['mtm_returns'][index] + ((mtm['mtm_returns'][index + 1] - mtm['mtm_returns'][index]) * ((1 - confidence_level) - mtm['cum_decay_weights'][index]) / (mtm['cum_decay_weights'][index + 1] - mtm['cum_decay_weights'][index] ))
    
                  VaR_exact_one_day =  ((total_mtm[1] * (interpolated_return_exact)))
    
                  if((((1 - confidence_level) - mtm['cum_decay_weights'][index]) < (mtm['cum_decay_weights'][index + 1] - (1 - confidence_level) ))):
            
                            interpolated_return_nearby = mtm['mtm_returns'][index]
                  else:
                            index = len(mtm1['cum_decay_weights'])
                            interpolated_return_nearby = mtm['mtm_returns'][index + 1]
    
                            VaR_nearby_one_day = np.abs(total_mtm['mtm_bc'][0] * (interpolated_return_nearby))

# %%
#VaR_one_day=data.frame(Decay_factor=decay_factor, Holding_period=holding_period, exact_one_day_VaR=VaR_exact_one_day, nearby_one_day_VaR=VaR_nearby_one_day)
VaR_one_day = pd.DataFrame(Decay_factor=decay_factor, Holding_period=holding_period, exact_one_day_VaR=VaR_exact_one_day, nearby_one_day_VaR=VaR_nearby_one_day)

# %%
if decay_factor == 0:
    Bondwise_VAR = total_change_in_MTM.groupby('instrument')
    
        change_in_MTM_sorted = sorted(total_change_in_mtm, reverse = True)
        VaR_exact_one_day = -(np.quantile(total_change_in_MTM, 0.01))
        nearby = np.floor(confidence_level * len(change_in_MTM_sorted))
        nearby = int(nearby)
        nearby_nxt = nearby + 1

        diff1 = pd.to_numeric(VaR_exact_one_day + change_in_MTM_sorted[nearby])
        diff2 = pd.to_numeric(- change_in_MTM_sorted[nearby_nxt] - VaR_exact_one_day)

        if (diff1 == diff2):
            VaR_nearby_one_day = - change_in_MTM_sorted[nearby + 1]
        elif (diff1 < diff2):
            VaR_nearby_one_day = - change_in_MTM_sorted[nearby]
        else:
            VaR_nearby_one_day = - change_in_MTM_sorted[nearby + 1]

else:
    #decay_weights <- ((1-decay_factor)* c(decay_factor^(0:(length(unique(x$env))-2)))/(1-decay_factor^((length(unique(x$env))-1))))
    
    decay_weights = (1-decay_factor)* ((decay_factor ** range(0,(len(change_df['idx'].unique())-1)))/((1 - decay_factor) ** (len(change_df['idx'].unique() -1))))
    total_mtm = change_df.groupby('idx')[['mtm_bc']].sum
    mtm_returns = []

    for i in range(1,(len(change_df['idx'].unique() -1))):
                   fv = total_mtm['mtm_bc'][0]
                   returns = (total_mtm['mtm_bc'][i] - fv)/fv
                   mtm_returns.append(returns) 
                    
    decay_weights = pd.DataFrame(decay_weights, columns = ['decay_weights'])
    mtm_returns = pd.DataFrame(mtm_returns, columns = ['mtm_returns'])
    mtm = pd.concat([mtm_returns,decay_weights], axis = 1)
    mtm = mtm.sort_values(['mtm_returns'])
    mtm['cum_decay_weights'] = np.cumsum(mtm['decay_weights'])
    a = 1-confidence_level
    mtm1 = mtm.loc[mtm['cum_decay_weights'] < a]
                                         
    if (len(mtm1)==0):
                  VaR_exact_equity_hp = np.abs(- mtm['mtm_returns'][0] * total_mtm['mtm_bc'][0])

                  VaR_nearby_equity_hp = VaR_exact_equity_hp

    else:
                  index = len(mtm1['cum_decay_weights'])
                                         
                  interpolated_return_exact = mtm['mtm_returns'][index] + ((mtm['mtm_returns'][index + 1] - mtm['mtm_returns'][index]) * ((1 - confidence_level) - mtm['cum_decay_weights'][index]) / (mtm['cum_decay_weights'][index + 1] - mtm['cum_decay_weights'][index] ))
    
                  VaR_exact_equity_hp =  ((total_mtm[1] * (interpolated_return_exact)))
    
                  if((((1 - confidence_level) - mtm['cum_decay_weights'][index]) < (mtm['cum_decay_weights'][index + 1] - (1 - confidence_level) ))):
            
                            interpolated_return_nearby = mtm['mtm_returns'][index]
                  else:
                            index = len(mtm1['cum_decay_weights'])
                            interpolated_return_nearby = mtm['mtm_returns'][index + 1]
    
                            VaR_nearby_equity_hp = np.abs(total_mtm['mtm_bc'][0] * (interpolated_return_nearby))

# %%
Bondwise_VaR<- ddply(Result, "instrument", function(x){
    
    decay_weights <- ((1-decay_factor)* c(decay_factor^(0:(length(unique(x$env))-2)))/(1-decay_factor^((length(unique(x$env))-1))))
    
    total_mtm <- tapply(x$all_mtm,x$env, sum)
    
    mtm_returns <- NULL
    
    for(i in 1 : (length(unique(Result$env))-1))
    {
      
      mtm_returns[i] = (total_mtm[i + 1] - total_mtm[1])/total_mtm[1]
      
    }
    
    mtm <- data.frame(mtm_returns,decay_weights)
    mtm1 <- mtm[order(mtm_returns),]
    mtm1$cum_decay_weights <- cumsum(mtm1$decay_weights)
    
    mtm <- data.frame(mtm_returns,decay_weights)
    mtm <- mtm[order(mtm_returns),]
    mtm$cum_decay_weights <- cumsum(mtm$decay_weights)
    
    mtm1 <- subset(mtm, cum_decay_weights < 1 - confidence_level)
    
    if(length(mtm1$cum_decay_weights) == 0)
    {
      
      VaR_exact_one_day <- abs(- mtm$mtm_returns[1] * total_mtm[1])
      
      VaR_nearby_one_day <- VaR_exact_one_day
      
      
    }else
      
    {
      
      index <- length(mtm1$cum_decay_weights)
      
      # _________________________________________________________________________________________________________
      
      # Exact Percentile
      
      interpolated_return_exact <- mtm$mtm_returns[index] + ((mtm$mtm_returns[index + 1] - mtm$mtm_returns[index]) * ((1 - confidence_level) - mtm$cum_decay_weights[index]) / (mtm$cum_decay_weights[index + 1] - mtm$cum_decay_weights[index]))
      
      VaR_exact_one_day <-  abs(total_mtm[1] * (interpolated_return_exact))
      
      # _________________________________________________________________________________________________________
      
      # Nearby Percentile
      
      if (((1-confidence_level)- mtm$cum_decay_weights[index]) < (mtm$cum_decay_weights[index + 1] - (1-confidence_level)))
        
      {
        interpolated_return_nearby <- mtm$mtm_returns[index]
      }else
        
      {
        interpolated_return_nearby <- mtm$mtm_returns[index + 1]
      }
      
      VaR_nearby_one_day <- abs(total_mtm[1] * (interpolated_return_nearby))
      
    }
    return(data.frame(id=seq(1,length(unique(x$instrument))), instrument=unique(x$instrument), Decay_factor=decay_factor, Holding_period=holding_period, exact_one_day_VaR=VaR_exact_one_day, nearby_one_day_VaR=VaR_nearby_one_day))
  }) 
}

# %%
lis = [4,7,3,6]
lis
# Out:
# [4, 7, 3, 6]
